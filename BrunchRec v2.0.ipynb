# %% [markdown]
# ## Kakao arena 2nd Competition
# # "브런치 사용자를 위한 글 추천 대회"
# ### brunch 데이터를 활용해 사용자의 취향에 맞는 글을 예측하는 대회
# * 공식 홈페이지: https://arena.kakao.com/c/2
# * 베이스 코드: https://github.com/kakao-arena/brunch-article-recommendation
#
# ### BrunchRec
# * designed by **datartist**
# * 깃헙 주소: https://github.com/jihoo-kim/BrunchRec

# %% [markdown]
# ## 1. 라이브러리 및 원본데이터

# %%
## 라이브러리
import numpy as np
import pandas as pd
import os
import time
import glob
import pickle
import datetime
import warnings
from itertools import chain
from collections import Counter

directory = './res/'
warnings.filterwarnings(action='ignore')

# %%
## 원본데이터

startTime = time.time()

# users  // DataFrame (310758, 3)
users = pd.read_json(directory + '/users.json', lines=True)

# magazine  // DataFrame (27967, 2)
magazine = pd.read_json(directory + 'magazine.json', lines=True)

# metadata  // DataFrame (643104, 9)
metadata = pd.read_json(directory + 'metadata.json', lines=True)

# dev.users  // List (3000)
f = open('./res/predict/dev.users')
dev_users = f.read().splitlines()
f.close()

# test.users  // List (5000)
f = open('./res/predict/test.users')
test_users = f.read().splitlines()
f.close()

# read  // DataFrame (3507097, 5)
read_file_lst = glob.glob('./res/read/*')
exclude_file_lst = ['read.tar']
read_df_lst = []
for f in read_file_lst:
    file_name = os.path.basename(f)
    if file_name in exclude_file_lst:
        print(file_name)
    else:
        df_temp = pd.read_csv(f, header=None, names=['raw'])
        df_temp['dt'] = file_name[:8]
        df_temp['hr'] = file_name[8:10]
        df_temp['user_id'] = df_temp['raw'].str.split(' ').str[0]
        df_temp['article_id'] = df_temp['raw'].str.split(' ').str[1:].str.join(' ').str.strip()
        read_df_lst.append(df_temp)
read = pd.concat(read_df_lst)

# read_raw  // DataFrame (22110706, 4)
def chainer(s):
    return list(chain.from_iterable(s.str.split(' ')))

read_cnt_by_user = read['article_id'].str.split(' ').map(len)

read_raw = pd.DataFrame({'dt': np.repeat(read['dt'], read_cnt_by_user),
                         'hr': np.repeat(read['hr'], read_cnt_by_user),
                         'user_id': np.repeat(read['user_id'], read_cnt_by_user),
                         'article_id': chainer(read['article_id'])})

endTime = time.time() - startTime
print(int(endTime), 'seconds', '=', int(endTime/60), 'minutes')
# Out:
# 67 seconds = 1 minutes

# %% [markdown]
# ## 2. 전처리 관련 함수

# %%
def get_unix_time(reg_ts):
    string_time = str(reg_ts)[:4]+'-'+str(reg_ts)[4:6]+'-'+str(reg_ts)[6:8]+' 00:00:00'
    unix_time = time.mktime(datetime.datetime.strptime(string_time, '%Y-%m-%d %H:%M:%S').timetuple())*1000
    
    return unix_time

# %%
## read_raw 'dt' 전처리 (날짜 컬럼의 자료형 변환 string -> int)
def read_raw_preprocessing(read_raw_df):
    
    if type(read_raw_df['dt'].values[0]) == type('string'):
        dt = read_raw_df['dt'].tolist()
        read_raw_df['dt'] = [int (i) for i in dt]
        print('read_raw_df preprocessing completed!')

    else:
        print('already preprocessed!')
        
    return read_raw_df

# %%
## metadata 'view' 전처리 (일정 기간 동안의 조회수 recent_view와 전체 기간 동안의 조회수 view 저장)
def metadata_preprocessing(metadata_df, read_raw_df, from_dt, to_dt):
    
    if 'recent_view' in metadata_df.keys():
        print('already preprocessed!')
        
    else:
        view = read_raw.groupby('article_id').count()['user_id']
        view_df = pd.DataFrame({'id':view.index, 'view':view.values})
        metadata_df = pd.merge(metadata_df, view_df, how='left', on='id')
        metadata_df['view'] = metadata_df['view'].fillna(0)
        
        partial_read = read_raw_df[(read_raw_df['dt'] >= from_dt) & (read_raw_df['dt'] <= to_dt)]
        recent_view = partial_read.groupby('article_id').count()['user_id']
        recent_view_df = pd.DataFrame({'id':recent_view.index, 'recent_view':recent_view.values})
        metadata_df = pd.merge(metadata_df, recent_view_df, how='left', on='id')
        metadata_df['recent_view'] = metadata_df['recent_view'].fillna(0)
        print('metadata_df preprocessing completed!')

    return metadata_df

# %%
## target_df 생성 (users에 없는 user_id 추가)
def target_df_generator(target_users_list, users_df):
    
    target_df = users_df[users_df['id'].isin(target_users_list)]
    
    for target_user in target_users_list:
        if (target_user in target_df['id'].tolist()) == False:
            new_df = pd.DataFrame({'following_list':[[]], 'id':[target_user], 'keyword_list':[[]]})
            target_df = target_df.append(new_df)
    
    return target_df

# %%
## target_df 'read' 전처리 (전체 기간 동안 target user가 본 article을 저장)
def target_read_article(target_df, read_raw_df, file):
    
    if os.path.isfile(file):        
        with open(file,"rb") as fr:
            target_read_article = pickle.load(fr)

        target_df['read'] = target_read_article
    
    else:
        target_read_article = []
        iteration = 0
        
        # target user가 전체 기간 동안 본 글의 article_id 저장 (중복 허용)
        for idx in target_df['id'].values.tolist():
            read_list = read_raw_df[read_raw_df['user_id']==idx]
            read_list = read_list[read_list['article_id'].str.startswith('@')]['article_id'].tolist()
            target_read_article.append(read_list)

            # 진행 상황 표시
            iteration += 1
            print(iteration, '/', str(len(target_df['id'].values.tolist())), 'completed')
            
        with open(file,"wb") as fw:
            pickle.dump(target_read_article, fw)
        
        target_df['read'] = target_read_article
            
    return target_df

# %%
## target_df 'recent' 전처리 (일정 기간 동안 target user가 본 article을 저장)
def target_recent_article(target_df, read_raw_df, from_dt, to_dt, file):
    
    if os.path.isfile(file):        
        with open(file,"rb") as fr:
            target_recent_article = pickle.load(fr)

        target_df['recent'] = target_recent_article
    
    else:
        target_recent_article = []
        iteration = 0
        
        # target user가 일정 기간 동안 본 글의 article_id 저장 (중복 허용)
        partial_read = read_raw_df[(read_raw_df['dt'] >= from_dt) & (read_raw_df['dt'] <= to_dt)]
        
        for idx in target_df['id'].values.tolist():    
            read_list = partial_read[partial_read['user_id']==idx]
            read_list = read_list[read_list['article_id'].str.startswith('@')]['article_id'].tolist()
            target_recent_article.append(read_list)

            # 진행 상황 표시
            iteration += 1
            print(iteration, '/', str(len(target_df['id'].values.tolist())), 'completed')
            
        with open(file,"wb") as fw:
            pickle.dump(target_recent_article, fw)
        
        target_df['recent'] = target_recent_article
            
    return target_df

# %%
# target_df 'following' 전처리 (target user가 본 following의 빈도수 저장)
def target_read_following(target_df, mode, file):
    
    if os.path.isfile(file):
        with open(file,"rb") as fr:
            target_read_following = pickle.load(fr)
        target_df[mode+'_following'] = target_read_following
    
    else:
        target_read_following = []
        iteration = 0

        for idx in target_df['id'].values.tolist():
            # following_frequency -> read_list 중에서 해당 작가(f_id)의 글의 빈도수
            following_frequency = {}
            
            # read_list- > target user의 read_list
            read_list = target_df[target_df['id']==idx][mode].values[0][:]
            
            if len(read_list) > 0:
                read_series = pd.Series(read_list)

                # f_list -> target user의 following_list (구독작가 리스트)
                f_list = target_df[target_df['id']==idx]['following_list'].values[0][:]  
                for i in range(len(f_list)):
                    f_list[i] = f_list[i] + '_'

                for f_id in f_list:
                    frequency = len(read_series[read_series.str.startswith(f_id)].tolist())
                    if frequency > 0:
                        following_frequency[f_id[:-1]]=frequency
                        
            target_read_following.append(following_frequency)

            # 진행 상황 표시
            iteration += 1
            print(iteration, '/', str(len(target_df['id'].values.tolist())), 'completed')
            
        with open(file,"wb") as fw:
            pickle.dump(target_read_following, fw)
        target_df[mode+'_following'] = target_read_following
    
    return target_df

# %%
# target_df 'magazine' 전처리 (target user가 본 magazine의 빈도수 저장)
def target_read_magazine(target_df, metadata_df, mode, file):
    
    if os.path.isfile(file):
        with open(file,"rb") as fr:
            target_read_magazine = pickle.load(fr)
        target_df[mode+'_magazine'] = target_read_magazine
    
    else:
        target_read_magazine = []
        iteration = 0

        for idx in target_df['id'].values.tolist():
            # target user가 읽은 글의 magazine_id 저장
            read_list = target_df[target_df['id']==idx][mode].values[0][:]
            magazine_list = metadata_df[metadata_df['id'].isin(read_list)]['magazine_id'].tolist()
            
            # magazine_id 빈도수 저장 (magazine이 아닌 0은 제외)
            magazine_frequency = Counter(magazine_list)
            del magazine_frequency[0]
            target_read_magazine.append(magazine_frequency)

            # 진행 상황 표시
            iteration += 1
            print(iteration, '/', str(len(target_df['id'].values.tolist())), 'completed')
            
        with open(file,"wb") as fw:
            pickle.dump(target_read_magazine, fw)
        target_df[mode+'_magazine'] = target_read_magazine
    
    return target_df

# %%
## target_df 'tag' 전처리 (target user가 본 article의 tag 빈도수 저장)
def target_read_tag(target_df, metadata_df, mode, file):
    
    if os.path.isfile(file):
        with open(file,"rb") as fr:
            target_read_tag = pickle.load(fr)
        target_df[mode+'_tag'] = target_read_tag
    
    else:
        target_read_tag = []
        iteration = 0

        for idx in target_df['id'].values.tolist():
            # read_list- > target user의 read_list
            read_list = target_df[target_df['id']==idx][mode].values[0][:]
            
            # 각 target user가 일정 기간 동안 읽은 글의 태그 합쳐서 저장 (중복 허용)
            keyword_list = metadata_df[metadata_df['id'].isin(read_list)]['keyword_list'].tolist()
            read_tag = sum(keyword_list, [])
            
            # 각 target user가 일정 기간 동안 읽은 글의 태그들의 빈도수 저장
            frequency = Counter(read_tag)
            target_read_tag.append(frequency)

            # 진행 상황 표시
            iteration += 1
            print(iteration, '/', str(len(target_df['id'].values.tolist())), 'completed')
        
        with open(file,"wb") as fw:
            pickle.dump(target_read_tag, fw)
        target_df[mode+'_tag'] = target_read_tag

    return target_df

# %%
## target_df 'interest' 전처리 (tag에서 빈도수가 높은 상위 top_N개 관심키워드 저장)
def target_read_interest(target_df, top_N, mode, file):
    
    if os.path.isfile(file):
        with open(file,"rb") as fr:
            target_read_interest = pickle.load(fr)
        target_df[mode+'_interest'] = target_read_interest
    
    else:
        target_read_interest = []
        iteration = 0      
        
        # read_tag에서 빈도수가 높은 상위 top_N개의 키워드 저장
        for idx in target_df['id'].values.tolist():
            interest = []
            
            rt = target_df[target_df['id']==idx][mode+'_tag'].values[0]
            sorted_rt = sorted(rt.items(), key=lambda x: x[1], reverse=True)
            
            for i in range(len(sorted_rt[:top_N])):
                interest.append(sorted_rt[:top_N][i][0])
                
            target_read_interest.append(interest)
            
            # 진행 상황 표시
            iteration += 1
            print(iteration, '/', str(len(target_df['id'].values.tolist())), 'completed')
        
        with open(file,"wb") as fw:
            pickle.dump(target_read_interest, fw)
        target_df[mode+'_interest'] = target_read_interest

    return target_df

# %%
## target_df 'behavior' 전처리 (target user의 글 소비 성향 저장)
def target_read_behavior(target_df, metadata_df, mode, file):
    
    if os.path.isfile(file):
        with open(file,"rb") as fr:
            ratio_list = pickle.load(fr)

    else:
        ratio_list = []

        if mode == 'recent':
            # 최근 기간 -> pop: view가 상위 1%인 글 / reg: 추천 기간 포함 1개월 동안 발행된 글
            pop_id = metadata_df[metadata_df['recent_view'] > metadata_df['recent_view'].quantile(0.99)]['id'].tolist()
            reg_id = metadata_df[metadata_df['reg_ts'] >= get_unix_time(20190215)]['id'].tolist()
        else:
            # 전체 기간 -> pop: view가 상위 20%인 글 / reg: 추천 기간 포함 6개월 동안 발행된 글
            pop_id = metadata_df[metadata_df['view'] > metadata_df['view'].quantile(0.80)]['id'].tolist()
            reg_id = metadata_df[metadata_df['reg_ts'] >= get_unix_time(20180915)]['id'].tolist()

        iteration = 0

        for idx in target_df['id'].values.tolist():
            read_list = target_df[target_df['id']==idx][mode].values[0][:]

            fr_dic = target_df[target_df['id']==idx][mode+'_following'].values[0]
            mr_dic = target_df[target_df['id']==idx][mode+'_magazine'].values[0]
            pop = pd.Series(read_list)[pd.Series(read_list).isin(pop_id)].tolist()
            reg = pd.Series(read_list)[pd.Series(read_list).isin(reg_id)].tolist()

            # f_ratio -> target user가 본 article 중에서 following의 비율
            # m_ratio -> target user가 본 article 중에서 magazine의 비율
            # p_ratio -> target user가 본 article 중에서 인기가 많은 글(view가 상위 1% or 20%)의 비율
            # r_ratio -> target user가 본 article 중에서 최근 발행된 글(reg_ts > 190215 or 180915)의 비율
            f_ratio, m_ratio, p_ratio, r_ratio = 0, 0, 0 ,0

            if len(read_list) >= 1:
                f_ratio = round(sum(fr_dic.values())/len(read_list), 2)
                m_ratio = round(sum(mr_dic.values())/len(read_list), 2)      
                p_ratio = round(len(pop)/len(read_list), 2)
                r_ratio = round(len(reg)/len(read_list), 2)

            ratio_list.append([f_ratio, m_ratio, p_ratio, r_ratio])

            # 진행 상황 표시
            iteration += 1
            print(iteration, '/', str(len(target_df['id'].values.tolist())), 'completed')
            
        with open(file,"wb") as fw:
            pickle.dump(ratio_list, fw)

    ratio_df = pd.DataFrame(ratio_list, columns=[mode+'_f_ratio', mode+'_m_ratio', mode+'_p_ratio', mode+'_r_ratio'])
    target_df.index = list(range(len(target_df)))
    target_df = pd.concat([target_df, ratio_df], axis=1)
    
    return target_df

# %%
# target user에 대한 전처리
def target_users_preprocessing(target_users_list, users_df, metadata_df, read_raw_df, from_dt, to_dt):
    
    target_df = target_df_generator(target_users_list, users)
    
    if target_users_list == dev_users:
        target = 'dev'
    elif target_users_list == test_users:
        target = 'test'

    # target user가 전체 기간 및 일정 기간 동안 읽은 글 저장
    target_df = target_read_article(target_df, read_raw_df, './pickle/'+target+'_read_article')
    target_df = target_recent_article(target_df, read_raw_df, from_dt, to_dt, './pickle/'+target+'_recent_article_'+str(from_dt)[2:])

    # target user가 읽은 글의 following 빈도수 저장
    target_df = target_read_following(target_df, 'read', './pickle/'+target+'_read_following')
    target_df = target_read_following(target_df, 'recent', './pickle/'+target+'_recent_following_'+str(from_dt)[2:])

    # target user가 읽은 글의 magazine 빈도수 저장
    target_df = target_read_magazine(target_df, metadata_df, 'read', './pickle/'+target+'_read_magazine')
    target_df = target_read_magazine(target_df, metadata_df, 'recent', './pickle/'+target+'_recent_magazine_'+str(from_dt)[2:])

    # target user가 읽은 글의 tag 빈도수 저장
    target_df = target_read_tag(target_df, metadata_df, 'read', './pickle/'+target+'_read_tag')
    target_df = target_read_tag(target_df, metadata_df, 'recent', './pickle/'+target+'_recent_tag_'+str(from_dt)[2:])

    # target user가 읽은 글의 tag 중 빈도수가 높은 top_N(=6)개의 interest 저장
    target_df = target_read_interest(target_df, 6, 'read', './pickle/'+target+'_read_interest')
    target_df = target_read_interest(target_df, 6, 'recent', './pickle/'+target+'_recent_interest_'+str(from_dt)[2:])

    # target user의 글 소비 경향 저장
    target_df = target_read_behavior(target_df, metadata_df, 'read', './pickle/'+target+'_read_behavior')
    target_df = target_read_behavior(target_df, metadata_df, 'recent', './pickle/'+target+'_recent_behavior')
    
    print('target_users_df preprocessing completed!')

    return target_df

# %% [markdown]
# ## 3. 추천 관련 함수

# %%
# 일정 기간 동안 조회수가 높은 인기 글을 추천
def popularity_based_recommend(idx, target_df, metadata_df, read_raw_df, r_list, recommended, p_ratio):
    
    already = r_list + recommended
    
    # 이미 본 글이나 추천된 글을 제외하고 view 순으로 n_rec만큼 추천
    n_rec = int((100-len(recommended)) * p_ratio)
    p_article = metadata_df[metadata_df['id'].isin(already)==False].sort_values(['view'],ascending=[False])
    popularity_based_recommend_list = p_article[:n_rec]['id'].tolist()
    
    return popularity_based_recommend_list

# %%
# target user가 최근 또는 전체 기간 동안 읽은 글 중에서 구독작가 글의 비율을 고려하여 추천
def following_based_recommend(idx, target_df, metadata_df, r_list, recommended, mode, f_ratio, sort_option):
    
    already = r_list + recommended
    following_based_recommend_list = []
    
    # fr_dic -> {f_id,빈도수}
    if mode == 'recent':
        fr_dic = target_df[target_df['id']==idx]['recent_following'].values[0]
    if mode == 'read':
        fr_dic = target_df[target_df['id']==idx]['read_following'].values[0]
        
    # sorted_fr -> 빈도수 순으로 정렬
    sorted_fr = sorted(fr_dic.items(), key=lambda x: x[1], reverse=True)
    
    for i in range(len(sorted_fr)):
        if sorted_fr[i][1] > 0:
            # n_rec -> 추천할 구독작가의 글의 개수 (빈도수가 높을수록 많이 추천됨)
            n_rec = int( (100-len(recommended)) * f_ratio * (sorted_fr[i][1]/sum(fr_dic.values())) )
            fr_article = metadata_df[metadata_df['user_id']==sorted_fr[i][0]]
            # 이미 본 글이나 이미 추천된 글을 제외하고 sort_option 순으로 n_rec만큼 추천
            fr_candidate = fr_article[fr_article['id'].isin(already)==False].sort_values([sort_option],ascending=[False])[:n_rec]['id'].tolist()
            following_based_recommend_list = following_based_recommend_list + fr_candidate
    
    return following_based_recommend_list

# %%
# target user가 최근에 읽은 글 중에서 매거진 글의 비율을 고려하여 추천
def magazine_based_recommend(idx, target_df, metadata_df, r_list, recommended, mode, m_ratio, sort_option):
    
    already = r_list + recommended
    magazine_based_recommend_list = []
    
    # mr_dic -> {m_id : 빈도수}
    if mode == 'recent':
        mr_dic = target_df[target_df['id']==idx]['recent_magazine'].values[0]
    if mode == 'read':
        mr_dic = target_df[target_df['id']==idx]['read_magazine'].values[0]
    
    # sorted_mr -> 빈도수 순으로 정렬
    sorted_mr = sorted(mr_dic.items(), key=lambda x: x[1], reverse=True)

    for i in range(len(sorted_mr)):
        # n_rec -> 추천할 매거진 글의 개수 (빈도수가 높을수록 많이 추천됨)
        n_rec = int( (100-len(recommended)) * m_ratio * (sorted_mr[i][1]/sum(mr_dic.values())) )
        mr_article = metadata_df[metadata_df['magazine_id']==sorted_mr[i][0]]
        # 이미 본 글이나 이미 추천된 글을 제외하고 sort_option 순으로 n_rec만큼 추천
        mr_candidate = mr_article[mr_article['id'].isin(already)==False].sort_values([sort_option],ascending=[False])[:n_rec]['id'].tolist()
        magazine_based_recommend_list = magazine_based_recommend_list + mr_candidate
    
    return magazine_based_recommend_list

# %%
# target user가 최근에 읽은 글들에서 자주 나오는 태그를 고려하여 추천
def tag_based_recommend(idx, target_df, metadata_df, r_list, recommended, recommend_list, mode, common_num, t_ratio, sort_option):
    
    already = r_list + recommended + sum(recommend_list, [])

    # user_interest -> target user의 interest (0 ~ 6개)
    if mode == 'recent':
        user_interest = target_df[target_df['id']== idx]['recent_interest'].values[0][:]
    if mode == 'read':
        user_interest = target_df[target_df['id']== idx]['read_interest'].values[0][:]

    # interest_article_id -> target user의 interest와 common_num개 이상 겹치는 글의 article_id
    interest_article_id = []
    for i in range(len(metadata_df)):
        if len(set(metadata_df['keyword_list'].values[i]) & set(user_interest)) >= common_num:
            interest_article_id.append(metadata_df['id'].values[i])

    # 이미 본 글이나 이미 추천된 글을 제외하고 sort_option 순으로 n_rec만큼 추천
    n_rec = int((100-len(recommended)) * t_ratio)
    t_article = metadata_df[metadata_df['id'].isin(interest_article_id)]
    tag_based_recommend_list = t_article[t_article['id'].isin(already)==False].sort_values([sort_option],ascending=[False])[:n_rec]['id'].tolist()

    return tag_based_recommend_list

# %%
def behavior_based_recommend(idx, target_df, metadata_all, metadata_reg, metadata_pop, metadata_hot, read_raw_df, r_list, recommended, recommend_list, mode, f_ratio, m_ratio):    
    
    f1 = following_based_recommend(idx, target_df, metadata_hot, r_list, recommended, mode, 1, 'view')
    recommended = recommended + f1

    f2 = following_based_recommend(idx, target_df, metadata_reg, r_list, recommended, mode, 1, 'reg_ts')
    recommended = recommended + f2
    
    p1 = popularity_based_recommend(idx, target_df, metadata_pop, read_raw_df, r_list, recommended, 0.1)
    recommended = recommended + p1

    m1 = magazine_based_recommend(idx, target_df, metadata_hot, r_list, recommended, mode, 0.5, 'view')
    recommended = recommended + m1
    
    t1 = tag_based_recommend(idx, target_df, metadata_hot, r_list, recommended, recommend_list, mode, 3, 1, 'view')
    recommended = recommended + t1
    
    m2 = magazine_based_recommend(idx, target_df, metadata_all, r_list, recommended, mode, 1, 'reg_ts')
    recommended = recommended + m2

    t2 = tag_based_recommend(idx, target_df, metadata_reg, r_list, recommended, recommend_list, mode, 2, 1, 'reg_ts')
    recommended = recommended + t2

    print('fr:'+str(int(f_ratio*100)).rjust(3)+'%,', 'mr:'+str(int(m_ratio*100)).rjust(3)+'%', '\t', \
          'f1:'+str(len(f1)).rjust(3)+',', 'f2:'+str(len(f2)).rjust(3)+',', 'p1:'+str(len(p1)).rjust(3)+',', \
          'm1:'+str(len(m1)).rjust(3)+',', 'm2:'+str(len(m2)).rjust(3)+',', \
          't1:'+str(len(t1)).rjust(3)+',', 't2:'+str(len(t2)).rjust(3)+',', 'p2:'+str(100-len(recommended)).rjust(3))

    return recommended

# %%
def recommender(target_list, target_df, metadata_df, read_raw_df, output_file):
    
    # 추천 실행 시간 측정
    startTime = time.time()
    # 최종 추천 리스트
    recommend_list = []
    
    # metadata_all -> 추천 기간 이후에 발행된 글을 제외한 metadata
    metadata_all = metadata_df[metadata_df['reg_ts'] < get_unix_time(20190314)]
    # metadata_reg -> 추천 기간을 포함한 최근 6개월 동안 발행된 글의 metadata
    metadata_reg = metadata_df[(metadata_df['reg_ts'] >= get_unix_time(20180914)) & (metadata_df['reg_ts'] < get_unix_time(20190314))]
    # metadata_pop -> 일정 기간 동안 view가 상위 20%인 글의 metadata
    metadata_pop = metadata_df[metadata_df['view'] > metadata_df['view'].quantile(0.80)]
    # metadata_hot -> 추천 기간 동안 발행되었고, view가 상위 1%인 글의 metadata
    metadata_hot = metadata_df[(metadata_df['view'] > metadata_df['view'].quantile(0.99)) & ((metadata_df['reg_ts'] >= get_unix_time(20190222)))]
 
    
    # recent_min -> 최소 recent 건수
    n_recent = []
    for i in range(len(target_df)):
        n_recent.append(len(target_df['recent'].values[i]))
    recent_min = np.percentile(np.array(n_recent), 20)

    # read_min -> 최소 read 건수
    n_read = []
    for i in range(len(target_df)):
        n_read.append(len(target_df['read'].values[i]))
    read_min = np.percentile(np.array(n_read), 20)
    
    # 진행 상황
    iteration = 0
    
    for idx in target_list:
        recommended = []

        r_list = target_df[target_df['id']==idx]['read'].values[0][:]
        recent = target_df[target_df['id']==idx]['recent'].values[0][:]
        read_f_ratio = target_df[target_df['id']==idx]['read_f_ratio'].values[0]
        read_m_ratio = target_df[target_df['id']==idx]['read_m_ratio'].values[0]
        recent_f_ratio = target_df[target_df['id']==idx]['recent_f_ratio'].values[0]
        recent_m_ratio = target_df[target_df['id']==idx]['recent_m_ratio'].values[0]

        
        if len(recent) > recent_min:
            print('read:'+str(len(r_list))+',', 'recent:'+str(len(recent)), '\t', 'mode: recent')
            recommended = behavior_based_recommend(idx, target_df, metadata_all, metadata_reg, metadata_pop, metadata_hot, read_raw_df, r_list, recommended, recommend_list, 'recent', recent_f_ratio, recent_m_ratio)
                
        elif len(r_list) > read_min:
            print('read:'+str(len(r_list))+',', 'recent:'+str(len(recent)), '\t', 'mode: read')
            recommended = behavior_based_recommend(idx, target_df, metadata_all, metadata_reg, metadata_pop, metadata_hot, read_raw_df, r_list, recommended, recommend_list, 'read', read_f_ratio, read_m_ratio)
            
        else:
            print('read:'+str(len(r_list))+',', 'recent:'+str(len(recent)), '\t', 'mode: else')
            recommended = behavior_based_recommend(idx, target_df, metadata_all, metadata_reg, metadata_pop, metadata_hot, read_raw_df, r_list, recommended, recommend_list, 'read', read_f_ratio, read_m_ratio)

        
        # 100개 되지 않았다면 popularity_based 추천
        if len(recommended) < 100:
            p2 = popularity_based_recommend(idx, target_df, metadata_hot, read_raw_df, r_list, recommended, 1.0)
            recommended = recommended + p2
            
        # 추천 리스트 맨 앞에 user_id 추가
        recommended.insert(0, idx)                
        recommend_list.append(recommended)        

        # 진행 상황 표시
        iteration += 1
        print('\t\t\t', 'Total:'+str(len(recommended)-1), '\t\t\t\t\t', str(iteration).rjust(4), '/', str(len(target_list)), 'completed', '\n')


    # 추천 리스트를 파일로 저장
    f = open(output_file, 'w')
    for i in range(len(recommend_list)):
        for j in range(len(recommend_list[i])):
            f.write(recommend_list[i][j])
            if j == (len(recommend_list[i]) - 1):
                continue
            f.write(' ')
        f.write('\n')
    f.close()
    print('recommend.txt file saved..')
    print('completed!')
    
    endTime = time.time() - startTime
    print(int(endTime), 'seconds', '=', int(endTime/60), 'minutes')

    return recommend_list

# %% [markdown]
# ## 4. 메인

# %% [markdown]
# ### Step 1. 전처리

# %%
startTime = time.time()

read_raw = read_raw_preprocessing(read_raw)
metadata = metadata_preprocessing(metadata, read_raw, 20190215, 20190228)
dev = target_users_preprocessing(dev_users, users, metadata, read_raw, 20190215, 20190228)

endTime = time.time() - startTime
print(int(endTime), 'seconds', '=', int(endTime/60), 'minutes')
# Out:
# already preprocessed!
# already preprocessed!
# target_users_df preprocessing completed!
# 1 seconds = 0 minutes

# %% [markdown]
# ### Step 2. 추천

# %%
recommend = recommender(dev_users, dev, metadata, read_raw, './recommend.txt')
# Out:
# read:103, recent:28 	 mode: recent
# fr: 14%, mr: 43% 	 f1:  1, f2:  2, p1:  9, m1:  1, m2: 75, t1:  0, t2: 12, p2:  0
# 			 Total:100 					    1 / 3000 completed
#
# read:44, recent:3 	 mode: read
# fr: 73%, mr: 86% 	 f1:  2, f2: 87, p1:  1, m1:  0, m2:  2, t1:  0, t2:  8, p2:  0
# 			 Total:100 					    2 / 3000 completed
#
# read:23, recent:3 	 mode: else
# fr: 61%, mr: 48% 	 f1:  1, f2:  8, p1:  9, m1:  0, m2: 33, t1:  0, t2: 13, p2: 36
# 			 Total:100 					    3 / 3000 completed
#
# read:59, recent:20 	 mode: recent
# fr: 80%, mr:  5% 	 f1:  1, f2:  9, p1:  9, m1:  0, m2: 81, t1:  0, t2:  0, p2:  0
# 			 Total:100 					    4 / 3000 completed
#
# read:413, recent:36 	 mode: recent
# fr: 78%, mr: 22% 	 f1:  0, f2: 57, p1:  4, m1:  0, m2: 28, t1:  0, t2: 11, p2:  0
# 			 Total:100 					    5 / 3000 completed
#
# read:5, recent:5 	 mode: else
# fr:100%, mr: 40% 	 f1:  1, f2: 20, p1:  7, m1:  0, m2:  0, t1:  0, t2:  7, p2: 65
# 			 Total:100 					    6 / 3000 completed
#
# read:95, recent:14 	 mode: recent
# fr: 86%, mr: 21% 	 f1:  1, f2: 35, p1:  6, m1:  0, m2: 11, t1:  0, t2: 47, p2:  0
# 			 Total:100 					    7 / 3000 completed
#
# read:105, recent:10 	 mode: recent
# fr: 80%, mr: 60% 	 f1:  0, f2: 60, p1:  4, m1:  1, m2: 14, t1:  0, t2: 21, p2:  0
# 			 Total:100 					    8 / 3000 completed
#
# read:416, recent:26 	 mode: recent
# fr: 54%, mr: 38% 	 f1:  1, f2: 73, p1:  2, m1:  1, m2:  7, t1:  0, t2: 16, p2:  0
# 			 Total:100 					    9 / 3000 completed
#
# read:5, recent:5 	 mode: else
# fr:  0%, mr: 80% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 56, t1:  0, t2: 18, p2: 16
# 			 Total:100 					   10 / 3000 completed
#
# read:4, recent:4 	 mode: else
# fr: 75%, mr: 75% 	 f1:  0, f2: 34, p1:  6, m1:  0, m2: 42, t1:  0, t2: 11, p2:  7
# 			 Total:100 					   11 / 3000 completed
#
# read:1542, recent:72 	 mode: recent
# fr:  3%, mr: 40% 	 f1:  1, f2: 10, p1:  8, m1:  3, m2: 65, t1:  0, t2: 13, p2:  0
# 			 Total:100 					   12 / 3000 completed
#
# read:271, recent:4 	 mode: read
# fr: 65%, mr: 73% 	 f1:  1, f2: 52, p1:  4, m1:  0, m2:  9, t1:  0, t2: 34, p2:  0
# 			 Total:100 					   13 / 3000 completed
#
# read:3783, recent:498 	 mode: recent
# fr: 40%, mr: 44% 	 f1:  3, f2: 49, p1:  4, m1:  0, m2:  8, t1:  0, t2: 36, p2:  0
# 			 Total:100 					   14 / 3000 completed
#
# read:326, recent:47 	 mode: recent
# fr: 94%, mr: 36% 	 f1:  2, f2: 52, p1:  4, m1:  0, m2: 26, t1:  0, t2: 16, p2:  0
# 			 Total:100 					   15 / 3000 completed
#
# read:1251, recent:563 	 mode: recent
# fr: 40%, mr: 39% 	 f1:  4, f2: 48, p1:  4, m1:  0, m2:  9, t1:  0, t2: 35, p2:  0
# 			 Total:100 					   16 / 3000 completed
#
# read:111, recent:36 	 mode: recent
# fr: 67%, mr: 53% 	 f1:  1, f2: 19, p1:  8, m1:  1, m2: 40, t1:  0, t2: 31, p2:  0
# 			 Total:100 					   17 / 3000 completed
#
# read:53, recent:13 	 mode: recent
# fr:  0%, mr: 69% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 67, t1:  0, t2: 23, p2:  0
# 			 Total:100 					   18 / 3000 completed
#
# read:1838, recent:84 	 mode: recent
# fr:  7%, mr: 45% 	 f1:  2, f2: 65, p1:  3, m1:  0, m2:  7, t1:  0, t2: 23, p2:  0
# 			 Total:100 					   19 / 3000 completed
#
# read:364, recent:9 	 mode: recent
# fr:100%, mr: 56% 	 f1:  1, f2: 22, p1:  7, m1:  0, m2: 70, t1:  0, t2:  0, p2:  0
# 			 Total:100 					   20 / 3000 completed
#
# read:114, recent:18 	 mode: recent
# fr: 33%, mr: 22% 	 f1:  2, f2: 74, p1:  2, m1:  0, m2: 13, t1:  0, t2:  9, p2:  0
# 			 Total:100 					   21 / 3000 completed
#
# read:4, recent:4 	 mode: else
# fr:  0%, mr: 50% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 90, t1:  0, t2:  0, p2:  0
# 			 Total:100 					   22 / 3000 completed
#
# read:64, recent:25 	 mode: recent
# fr:  0%, mr: 52% 	 f1:  0, f2:  0, p1: 10, m1:  3, m2: 70, t1:  0, t2: 17, p2:  0
# 			 Total:100 					   23 / 3000 completed
#
# read:153, recent:153 	 mode: recent
# fr: 34%, mr: 37% 	 f1:  2, f2: 22, p1:  7, m1:  0, m2: 54, t1:  0, t2: 15, p2:  0
# 			 Total:100 					   24 / 3000 completed
#
# read:16, recent:4 	 mode: else
# fr: 69%, mr: 62% 	 f1:  2, f2: 54, p1:  4, m1:  1, m2: 29, t1:  0, t2: 10, p2:  0
# 			 Total:100 					   25 / 3000 completed
#
# read:70, recent:29 	 mode: recent
# fr:  0%, mr: 66% 	 f1:  0, f2:  0, p1: 10, m1:  2, m2: 77, t1:  0, t2: 11, p2:  0
# 			 Total:100 					   26 / 3000 completed
#
# read:211, recent:145 	 mode: recent
# fr: 28%, mr: 19% 	 f1:  0, f2: 13, p1:  8, m1:  1, m2: 47, t1:  0, t2: 31, p2:  0
# 			 Total:100 					   27 / 3000 completed
#
# read:65, recent:54 	 mode: recent
# fr:  7%, mr: 70% 	 f1:  0, f2: 60, p1:  4, m1:  0, m2:  2, t1:  0, t2: 34, p2:  0
# 			 Total:100 					   28 / 3000 completed
#
# read:5, recent:5 	 mode: else
# fr: 80%, mr: 20% 	 f1:  0, f2: 11, p1:  8, m1:  0, m2: 34, t1:  0, t2: 47, p2:  0
# 			 Total:100 					   29 / 3000 completed
#
# read:30, recent:3 	 mode: read
# fr:  0%, mr: 73% 	 f1:  0, f2:  0, p1: 10, m1:  1, m2: 13, t1:  0, t2: 76, p2:  0
# 			 Total:100 					   30 / 3000 completed
#
# read:548, recent:39 	 mode: recent
# fr: 36%, mr: 23% 	 f1:  0, f2: 48, p1:  5, m1:  0, m2: 42, t1:  0, t2:  5, p2:  0
# 			 Total:100 					   31 / 3000 completed
#
# read:176, recent:27 	 mode: recent
# fr: 15%, mr: 48% 	 f1:  0, f2: 10, p1:  9, m1:  0, m2: 61, t1:  0, t2: 20, p2:  0
# 			 Total:100 					   32 / 3000 completed
#
# read:100, recent:20 	 mode: recent
# fr:  0%, mr: 65% 	 f1:  0, f2:  0, p1: 10, m1:  1, m2: 79, t1:  0, t2: 10, p2:  0
# 			 Total:100 					   33 / 3000 completed
#
# read:1509, recent:125 	 mode: recent
# fr: 26%, mr: 37% 	 f1:  0, f2: 89, p1:  1, m1:  0, m2:  0, t1:  0, t2: 10, p2:  0
# 			 Total:100 					   34 / 3000 completed
#
# read:387, recent:18 	 mode: recent
# fr:  0%, mr: 67% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 50, t1:  0, t2: 40, p2:  0
# 			 Total:100 					   35 / 3000 completed
#
# read:11, recent:8 	 mode: recent
# fr:  0%, mr: 38% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 90, t1:  0, t2:  0, p2:  0
# 			 Total:100 					   36 / 3000 completed
#
# read:673, recent:389 	 mode: recent
# fr:  2%, mr: 33% 	 f1:  1, f2: 53, p1:  4, m1:  2, m2: 37, t1:  0, t2:  3, p2:  0
# 			 Total:100 					   37 / 3000 completed
#
# read:2, recent:2 	 mode: else
# fr:  0%, mr:100% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 50, t1:  0, t2: 40, p2:  0
# 			 Total:100 					   38 / 3000 completed
#
# read:76, recent:8 	 mode: recent
# fr: 50%, mr: 50% 	 f1:  7, f2: 93, p1:  0, m1:  0, m2:  0, t1:  0, t2:  0, p2:  0
# 			 Total:100 					   39 / 3000 completed
#
# read:30, recent:9 	 mode: recent
# fr: 67%, mr: 22% 	 f1:  1, f2:  7, p1:  9, m1:  0, m2: 22, t1:  0, t2: 61, p2:  0
# 			 Total:100 					   40 / 3000 completed
#
# read:1639, recent:533 	 mode: recent
# fr: 55%, mr: 40% 	 f1:  0, f2: 76, p1:  2, m1:  0, m2:  8, t1:  1, t2: 13, p2:  0
# 			 Total:100 					   41 / 3000 completed
#
# read:2917, recent:149 	 mode: recent
# fr: 56%, mr: 32% 	 f1:  6, f2: 55, p1:  3, m1:  0, m2: 15, t1:  0, t2: 21, p2:  0
# 			 Total:100 					   42 / 3000 completed
#
# read:231, recent:13 	 mode: recent
# fr: 38%, mr: 92% 	 f1:  0, f2: 33, p1:  6, m1:  0, m2: 46, t1:  0, t2: 15, p2:  0
# 			 Total:100 					   43 / 3000 completed
#
# read:19, recent:11 	 mode: recent
# fr:  0%, mr: 91% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 87, t1:  0, t2:  3, p2:  0
# 			 Total:100 					   44 / 3000 completed
#
# read:195, recent:7 	 mode: recent
# fr: 43%, mr: 56% 	 f1:  1, f2: 38, p1:  6, m1:  0, m2: 43, t1:  0, t2: 12, p2:  0
# 			 Total:100 					   45 / 3000 completed
#
# read:290, recent:21 	 mode: recent
# fr: 71%, mr: 71% 	 f1:  1, f2: 38, p1:  6, m1:  0, m2: 14, t1:  0, t2: 41, p2:  0
# 			 Total:100 					   46 / 3000 completed
#
# read:204, recent:19 	 mode: recent
# fr:  0%, mr: 84% 	 f1:  0, f2:  0, p1: 10, m1:  2, m2: 69, t1:  0, t2: 19, p2:  0
# 			 Total:100 					   47 / 3000 completed
#
# read:164, recent:164 	 mode: recent
# fr: 74%, mr: 15% 	 f1:  0, f2: 33, p1:  6, m1:  0, m2: 37, t1:  0, t2: 24, p2:  0
# 			 Total:100 					   48 / 3000 completed
#
# read:411, recent:411 	 mode: recent
# fr: 68%, mr: 14% 	 f1:  1, f2: 20, p1:  7, m1:  1, m2: 60, t1:  0, t2: 11, p2:  0
# 			 Total:100 					   49 / 3000 completed
#
# read:617, recent:57 	 mode: recent
# fr:  0%, mr: 47% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 70, t1:  0, t2: 20, p2:  0
# 			 Total:100 					   50 / 3000 completed
#
# read:0, recent:0 	 mode: else
# fr:  0%, mr:  0% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2:  0, t1:  0, t2:  0, p2: 90
# 			 Total:100 					   51 / 3000 completed
#
# read:20, recent:7 	 mode: recent
# fr: 43%, mr: 56% 	 f1:  7, f2: 65, p1:  2, m1:  0, m2: 20, t1:  0, t2:  6, p2:  0
# 			 Total:100 					   52 / 3000 completed
#
# read:18, recent:12 	 mode: recent
# fr: 83%, mr: 25% 	 f1:  1, f2: 15, p1:  8, m1:  0, m2: 69, t1:  0, t2:  7, p2:  0
# 			 Total:100 					   53 / 3000 completed
#
# read:174, recent:174 	 mode: recent
# fr: 89%, mr: 40% 	 f1:  0, f2: 99, p1:  0, m1:  0, m2:  0, t1:  0, t2:  1, p2:  0
# 			 Total:100 					   54 / 3000 completed
#
# read:106, recent:70 	 mode: recent
# fr: 73%, mr: 46% 	 f1:  0, f2: 38, p1:  6, m1:  0, m2: 41, t1:  0, t2: 15, p2:  0
# 			 Total:100 					   55 / 3000 completed
#
# read:379, recent:11 	 mode: recent
# fr: 27%, mr: 55% 	 f1:  0, f2: 49, p1:  5, m1:  0, m2: 43, t1:  0, t2:  3, p2:  0
# 			 Total:100 					   56 / 3000 completed
#
# read:8, recent:8 	 mode: recent
# fr: 25%, mr: 75% 	 f1:  5, f2: 14, p1:  8, m1:  0, m2: 72, t1:  0, t2:  0, p2:  1
# 			 Total:100 					   57 / 3000 completed
#
# read:391, recent:5 	 mode: read
# fr:  6%, mr: 55% 	 f1:  1, f2: 35, p1:  6, m1:  0, m2:  0, t1:  0, t2: 58, p2:  0
# 			 Total:100 					   58 / 3000 completed
#
# read:134, recent:13 	 mode: recent
# fr: 62%, mr: 54% 	 f1:  2, f2: 21, p1:  7, m1:  0, m2: 33, t1:  0, t2:  2, p2: 35
# 			 Total:100 					   59 / 3000 completed
#
# read:2, recent:2 	 mode: else
# fr:100%, mr:100% 	 f1:  0, f2:  3, p1:  9, m1:  0, m2: 32, t1:  0, t2: 56, p2:  0
# 			 Total:100 					   60 / 3000 completed
#
# read:375, recent:12 	 mode: recent
# fr: 50%, mr: 83% 	 f1:  2, f2: 53, p1:  4, m1:  0, m2: 33, t1:  0, t2:  8, p2:  0
# 			 Total:100 					   61 / 3000 completed
#
# read:395, recent:27 	 mode: recent
# fr: 30%, mr: 52% 	 f1:  1, f2: 36, p1:  6, m1:  1, m2: 56, t1:  0, t2:  0, p2:  0
# 			 Total:100 					   62 / 3000 completed
#
# read:1185, recent:140 	 mode: recent
# fr:  4%, mr: 34% 	 f1:  1, f2:  7, p1:  9, m1:  1, m2: 34, t1:  0, t2: 48, p2:  0
# 			 Total:100 					   63 / 3000 completed
#
# read:652, recent:173 	 mode: recent
# fr: 43%, mr: 57% 	 f1:  8, f2: 62, p1:  3, m1:  0, m2:  0, t1:  0, t2: 27, p2:  0
# 			 Total:100 					   64 / 3000 completed
#
# read:2, recent:2 	 mode: else
# fr: 50%, mr:100% 	 f1:  0, f2: 58, p1:  4, m1:  0, m2:  0, t1:  0, t2:  5, p2: 33
# 			 Total:100 					   65 / 3000 completed
#
# read:351, recent:15 	 mode: recent
# fr: 60%, mr: 40% 	 f1:  1, f2: 27, p1:  7, m1:  0, m2: 46, t1:  0, t2: 19, p2:  0
# 			 Total:100 					   66 / 3000 completed
#
# read:154, recent:79 	 mode: recent
# fr: 57%, mr: 27% 	 f1:  0, f2: 25, p1:  7, m1:  3, m2: 51, t1:  0, t2: 14, p2:  0
# 			 Total:100 					   67 / 3000 completed
#
# read:670, recent:87 	 mode: recent
# fr: 18%, mr: 62% 	 f1:  0, f2: 55, p1:  4, m1:  0, m2: 11, t1:  0, t2: 30, p2:  0
# 			 Total:100 					   68 / 3000 completed
#
# read:1001, recent:109 	 mode: recent
# fr:100%, mr:  6% 	 f1:  3, f2: 46, p1:  5, m1:  0, m2:  0, t1:  0, t2: 46, p2:  0
# 			 Total:100 					   69 / 3000 completed
#
# read:392, recent:12 	 mode: recent
# fr: 50%, mr: 67% 	 f1:  1, f2: 98, p1:  0, m1:  0, m2:  0, t1:  0, t2:  1, p2:  0
# 			 Total:100 					   70 / 3000 completed
#
# read:10, recent:7 	 mode: recent
# fr:  0%, mr: 71% 	 f1:  0, f2:  0, p1: 10, m1:  1, m2: 72, t1:  0, t2: 17, p2:  0
# 			 Total:100 					   71 / 3000 completed
#
# read:592, recent:134 	 mode: recent
# fr: 25%, mr: 43% 	 f1:  7, f2: 59, p1:  3, m1:  0, m2:  6, t1:  0, t2: 25, p2:  0
# 			 Total:100 					   72 / 3000 completed
#
# read:310, recent:62 	 mode: recent
# fr: 23%, mr: 27% 	 f1:  1, f2: 10, p1:  8, m1:  0, m2: 54, t1:  0, t2: 27, p2:  0
# 			 Total:100 					   73 / 3000 completed
#
# read:20, recent:17 	 mode: recent
# fr: 82%, mr: 12% 	 f1:  1, f2: 41, p1:  5, m1:  0, m2: 14, t1:  0, t2: 39, p2:  0
# 			 Total:100 					   74 / 3000 completed
#
# read:190, recent:127 	 mode: recent
# fr: 50%, mr: 25% 	 f1:  0, f2:  4, p1:  9, m1:  0, m2: 71, t1:  0, t2: 16, p2:  0
# 			 Total:100 					   75 / 3000 completed
#
# read:28163, recent:9645 	 mode: recent
# fr: 79%, mr: 34% 	 f1:  0, f2: 46, p1:  5, m1:  0, m2:  5, t1:  0, t2: 44, p2:  0
# 			 Total:100 					   76 / 3000 completed
#
# read:162, recent:162 	 mode: recent
# fr: 47%, mr: 72% 	 f1:  1, f2: 88, p1:  1, m1:  0, m2:  0, t1:  0, t2: 10, p2:  0
# 			 Total:100 					   77 / 3000 completed
#
# read:548, recent:181 	 mode: recent
# fr: 81%, mr: 11% 	 f1:  5, f2: 12, p1:  8, m1:  0, m2: 32, t1:  0, t2: 43, p2:  0
# 			 Total:100 					   78 / 3000 completed
#
# read:176, recent:18 	 mode: recent
# fr:  6%, mr: 61% 	 f1:  1, f2:  5, p1:  9, m1:  1, m2: 71, t1:  0, t2: 13, p2:  0
# 			 Total:100 					   79 / 3000 completed
#
# read:23, recent:23 	 mode: recent
# fr: 83%, mr: 26% 	 f1:  1, f2: 57, p1:  4, m1:  0, m2: 33, t1:  0, t2:  5, p2:  0
# 			 Total:100 					   80 / 3000 completed
#
# read:81, recent:27 	 mode: recent
# fr: 48%, mr: 37% 	 f1:  9, f2: 75, p1:  1, m1:  0, m2:  9, t1:  0, t2:  6, p2:  0
# 			 Total:100 					   81 / 3000 completed
#
# read:125, recent:8 	 mode: recent
# fr:  0%, mr: 62% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 44, t1:  0, t2: 46, p2:  0
# 			 Total:100 					   82 / 3000 completed
#
# read:26, recent:26 	 mode: recent
# fr: 15%, mr: 42% 	 f1:  0, f2: 11, p1:  8, m1:  1, m2: 70, t1:  0, t2: 10, p2:  0
# 			 Total:100 					   83 / 3000 completed
#
# read:1, recent:1 	 mode: else
# fr:  0%, mr:100% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2:  3, t1:  0, t2:  5, p2: 82
# 			 Total:100 					   84 / 3000 completed
#
# read:171, recent:30 	 mode: recent
# fr:  0%, mr: 70% 	 f1:  0, f2:  0, p1: 10, m1:  2, m2: 72, t1:  0, t2: 16, p2:  0
# 			 Total:100 					   85 / 3000 completed
#
# read:216, recent:8 	 mode: recent
# fr: 88%, mr: 50% 	 f1:  1, f2: 31, p1:  6, m1:  0, m2: 41, t1:  0, t2: 21, p2:  0
# 			 Total:100 					   86 / 3000 completed
#
# read:353, recent:353 	 mode: recent
# fr: 94%, mr: 35% 	 f1:  1, f2: 20, p1:  7, m1:  0, m2: 40, t1:  0, t2: 32, p2:  0
# 			 Total:100 					   87 / 3000 completed
#
# read:424, recent:55 	 mode: recent
# fr:100%, mr: 24% 	 f1:  0, f2: 36, p1:  6, m1:  0, m2: 39, t1:  0, t2: 19, p2:  0
# 			 Total:100 					   88 / 3000 completed
#
# read:559, recent:129 	 mode: recent
# fr: 32%, mr: 33% 	 f1:  0, f2: 20, p1:  8, m1:  0, m2: 46, t1:  0, t2: 26, p2:  0
# 			 Total:100 					   89 / 3000 completed
#
# read:64, recent:34 	 mode: recent
# fr: 50%, mr: 68% 	 f1:  1, f2: 64, p1:  3, m1:  0, m2: 18, t1:  0, t2: 14, p2:  0
# 			 Total:100 					   90 / 3000 completed
#
# read:3, recent:1 	 mode: else
# fr:  0%, mr:100% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 49, t1:  0, t2:  2, p2: 39
# 			 Total:100 					   91 / 3000 completed
#
# read:3614, recent:656 	 mode: recent
# fr: 45%, mr: 30% 	 f1:  3, f2: 60, p1:  3, m1:  0, m2: 14, t1:  0, t2: 20, p2:  0
# 			 Total:100 					   92 / 3000 completed
#
# read:41, recent:7 	 mode: recent
# fr:  0%, mr:100% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 75, t1:  0, t2:  5, p2: 10
# 			 Total:100 					   93 / 3000 completed
#
# read:8, recent:7 	 mode: recent
# fr:100%, mr: 43% 	 f1:  1, f2: 31, p1:  6, m1:  0, m2: 27, t1:  0, t2: 35, p2:  0
# 			 Total:100 					   94 / 3000 completed
#
# read:1682, recent:274 	 mode: recent
# fr: 26%, mr: 39% 	 f1:  5, f2: 30, p1:  6, m1:  0, m2:  6, t1:  0, t2: 53, p2:  0
# 			 Total:100 					   95 / 3000 completed
#
# read:33, recent:4 	 mode: read
# fr: 27%, mr: 76% 	 f1:  0, f2: 99, p1:  0, m1:  0, m2:  0, t1:  0, t2:  1, p2:  0
# 			 Total:100 					   96 / 3000 completed
#
# read:354, recent:14 	 mode: recent
# fr:100%, mr: 21% 	 f1:  0, f2: 16, p1:  8, m1:  0, m2:  4, t1:  0, t2: 72, p2:  0
# 			 Total:100 					   97 / 3000 completed
#
# read:384, recent:35 	 mode: recent
# fr: 34%, mr: 37% 	 f1:  2, f2: 42, p1:  5, m1:  0, m2: 32, t1:  0, t2: 19, p2:  0
# 			 Total:100 					   98 / 3000 completed
#
# read:17, recent:1 	 mode: else
# fr: 41%, mr: 53% 	 f1:  1, f2: 54, p1:  4, m1:  0, m2: 32, t1:  0, t2:  9, p2:  0
# 			 Total:100 					   99 / 3000 completed
#
# read:0, recent:0 	 mode: else
# fr:  0%, mr:  0% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2:  0, t1:  0, t2:  0, p2: 90
# 			 Total:100 					  100 / 3000 completed
#
# read:0, recent:0 	 mode: else
# fr:  0%, mr:  0% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2:  0, t1:  0, t2:  0, p2: 90
# 			 Total:100 					  101 / 3000 completed
#
# read:257, recent:218 	 mode: recent
# fr: 55%, mr: 28% 	 f1:  1, f2: 37, p1:  6, m1:  1, m2: 15, t1:  0, t2: 40, p2:  0
# 			 Total:100 					  102 / 3000 completed
#
# read:36, recent:36 	 mode: recent
# fr: 25%, mr: 57% 	 f1:  0, f2:  8, p1:  9, m1:  2, m2: 62, t1:  0, t2: 19, p2:  0
# 			 Total:100 					  103 / 3000 completed
#
# read:26, recent:12 	 mode: recent
# fr: 33%, mr: 57% 	 f1:  0, f2: 46, p1:  5, m1:  0, m2: 35, t1:  0, t2: 14, p2:  0
# 			 Total:100 					  104 / 3000 completed
#
# read:492, recent:112 	 mode: recent
# fr: 93%, mr: 34% 	 f1:  1, f2: 77, p1:  2, m1:  0, m2: 10, t1:  0, t2: 10, p2:  0
# 			 Total:100 					  105 / 3000 completed
#
# read:1474, recent:12 	 mode: recent
# fr:100%, mr: 33% 	 f1:  0, f2: 58, p1:  4, m1:  0, m2: 16, t1:  0, t2: 22, p2:  0
# 			 Total:100 					  106 / 3000 completed
#
# read:6, recent:6 	 mode: else
# fr:100%, mr: 67% 	 f1:  1, f2: 24, p1:  7, m1:  0, m2:  0, t1:  0, t2: 52, p2: 16
# 			 Total:100 					  107 / 3000 completed
#
# read:18, recent:2 	 mode: else
# fr: 83%, mr: 83% 	 f1:  1, f2: 20, p1:  7, m1:  0, m2: 12, t1:  0, t2: 60, p2:  0
# 			 Total:100 					  108 / 3000 completed
#
# read:451, recent:89 	 mode: recent
# fr: 89%, mr: 31% 	 f1:  1, f2: 39, p1:  6, m1:  0, m2: 13, t1:  0, t2: 41, p2:  0
# 			 Total:100 					  109 / 3000 completed
#
# read:585, recent:68 	 mode: recent
# fr: 44%, mr: 54% 	 f1:  7, f2: 40, p1:  5, m1:  0, m2: 34, t1:  0, t2: 14, p2:  0
# 			 Total:100 					  110 / 3000 completed
#
# read:255, recent:70 	 mode: recent
# fr:  0%, mr: 39% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 76, t1:  0, t2: 14, p2:  0
# 			 Total:100 					  111 / 3000 completed
#
# read:143, recent:10 	 mode: recent
# fr: 60%, mr: 30% 	 f1:  0, f2: 16, p1:  8, m1:  0, m2: 27, t1:  0, t2: 23, p2: 26
# 			 Total:100 					  112 / 3000 completed
#
# read:11, recent:11 	 mode: recent
# fr:  0%, mr: 55% 	 f1:  0, f2:  0, p1: 10, m1:  1, m2: 80, t1:  0, t2:  9, p2:  0
# 			 Total:100 					  113 / 3000 completed
#
# read:489, recent:28 	 mode: recent
# fr: 21%, mr: 86% 	 f1:  0, f2: 31, p1:  6, m1:  1, m2: 42, t1:  0, t2: 20, p2:  0
# 			 Total:100 					  114 / 3000 completed
#
# read:9, recent:9 	 mode: recent
# fr:  0%, mr: 44% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 53, t1:  0, t2: 37, p2:  0
# 			 Total:100 					  115 / 3000 completed
#
# read:7, recent:7 	 mode: recent
# fr: 28%, mr: 28% 	 f1:  0, f2:  3, p1:  9, m1:  0, m2: 16, t1:  0, t2: 50, p2: 22
# 			 Total:100 					  116 / 3000 completed
#
# read:2044, recent:1923 	 mode: recent
# fr: 75%, mr: 34% 	 f1:  1, f2: 47, p1:  5, m1:  0, m2:  8, t1:  0, t2: 39, p2:  0
# 			 Total:100 					  117 / 3000 completed
#
# read:698, recent:16 	 mode: recent
# fr:  0%, mr: 62% 	 f1:  0, f2:  0, p1: 10, m1:  1, m2: 67, t1:  0, t2: 22, p2:  0
# 			 Total:100 					  118 / 3000 completed
#
# read:479, recent:14 	 mode: recent
# fr: 28%, mr: 21% 	 f1:  1, f2:  8, p1:  9, m1:  1, m2: 38, t1:  0, t2: 14, p2: 29
# 			 Total:100 					  119 / 3000 completed
#
# read:49, recent:16 	 mode: recent
# fr:  0%, mr: 69% 	 f1:  0, f2:  0, p1: 10, m1:  1, m2: 73, t1:  0, t2: 16, p2:  0
# 			 Total:100 					  120 / 3000 completed
#
# read:220, recent:4 	 mode: read
# fr: 65%, mr: 43% 	 f1:  4, f2: 77, p1:  1, m1:  0, m2:  4, t1:  0, t2: 14, p2:  0
# 			 Total:100 					  121 / 3000 completed
#
# read:509, recent:25 	 mode: recent
# fr: 56%, mr: 32% 	 f1:  0, f2: 17, p1:  8, m1:  0, m2:  7, t1:  0, t2: 68, p2:  0
# 			 Total:100 					  122 / 3000 completed
#
# read:13, recent:7 	 mode: recent
# fr:  0%, mr: 56% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 20, t1:  0, t2: 70, p2:  0
# 			 Total:100 					  123 / 3000 completed
#
# read:151, recent:10 	 mode: recent
# fr: 90%, mr: 60% 	 f1:  0, f2:  4, p1:  9, m1:  0, m2: 14, t1:  0, t2:  1, p2: 72
# 			 Total:100 					  124 / 3000 completed
#
# read:316, recent:100 	 mode: recent
# fr: 91%, mr: 17% 	 f1:  1, f2: 33, p1:  6, m1:  0, m2: 17, t1:  0, t2: 43, p2:  0
# 			 Total:100 					  125 / 3000 completed
#
# read:42, recent:42 	 mode: recent
# fr:  0%, mr: 40% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 75, t1:  0, t2: 15, p2:  0
# 			 Total:100 					  126 / 3000 completed
#
# read:309, recent:84 	 mode: recent
# fr:100%, mr: 20% 	 f1:  0, f2: 47, p1:  5, m1:  0, m2: 47, t1:  0, t2:  1, p2:  0
# 			 Total:100 					  127 / 3000 completed
#
# read:980, recent:102 	 mode: recent
# fr: 27%, mr: 34% 	 f1:  0, f2: 57, p1:  4, m1:  0, m2: 33, t1:  0, t2:  6, p2:  0
# 			 Total:100 					  128 / 3000 completed
#
# read:399, recent:399 	 mode: recent
# fr: 66%, mr: 48% 	 f1:  1, f2: 66, p1:  3, m1:  0, m2: 14, t1:  0, t2: 16, p2:  0
# 			 Total:100 					  129 / 3000 completed
#
# read:434, recent:97 	 mode: recent
# fr: 91%, mr: 41% 	 f1:  5, f2: 69, p1:  2, m1:  0, m2:  8, t1:  0, t2: 16, p2:  0
# 			 Total:100 					  130 / 3000 completed
#
# read:76, recent:76 	 mode: recent
# fr: 11%, mr: 30% 	 f1:  0, f2: 10, p1:  9, m1:  0, m2: 68, t1:  0, t2: 13, p2:  0
# 			 Total:100 					  131 / 3000 completed
#
# read:329, recent:45 	 mode: recent
# fr: 98%, mr: 64% 	 f1:  2, f2: 65, p1:  3, m1:  0, m2: 20, t1:  0, t2: 10, p2:  0
# 			 Total:100 					  132 / 3000 completed
#
# read:129, recent:1 	 mode: read
# fr: 16%, mr: 50% 	 f1:  0, f2: 19, p1:  8, m1:  0, m2: 66, t1:  0, t2:  7, p2:  0
# 			 Total:100 					  133 / 3000 completed
#
# read:561, recent:204 	 mode: recent
# fr: 39%, mr: 47% 	 f1:  1, f2: 50, p1:  4, m1:  0, m2: 14, t1:  0, t2: 31, p2:  0
# 			 Total:100 					  134 / 3000 completed
#
# read:242, recent:6 	 mode: read
# fr:  0%, mr: 70% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 19, t1:  0, t2: 71, p2:  0
# 			 Total:100 					  135 / 3000 completed
#
# read:2072, recent:52 	 mode: recent
# fr:  8%, mr: 48% 	 f1:  1, f2:  5, p1:  9, m1:  0, m2: 67, t1:  0, t2: 18, p2:  0
# 			 Total:100 					  136 / 3000 completed
#
# read:54, recent:14 	 mode: recent
# fr:  0%, mr: 71% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 86, t1:  0, t2:  4, p2:  0
# 			 Total:100 					  137 / 3000 completed
#
# read:34, recent:34 	 mode: recent
# fr:  0%, mr: 56% 	 f1:  0, f2:  0, p1: 10, m1:  1, m2: 50, t1:  0, t2: 39, p2:  0
# 			 Total:100 					  138 / 3000 completed
#
# read:12, recent:12 	 mode: recent
# fr: 83%, mr: 17% 	 f1:  0, f2:100, p1:  0, m1:  0, m2:  0, t1:  0, t2:  0, p2:  0
# 			 Total:100 					  139 / 3000 completed
#
# read:360, recent:5 	 mode: read
# fr: 62%, mr: 87% 	 f1:  2, f2: 53, p1:  4, m1:  0, m2: 12, t1:  0, t2: 29, p2:  0
# 			 Total:100 					  140 / 3000 completed
#
# read:110, recent:110 	 mode: recent
# fr:  2%, mr: 31% 	 f1:  1, f2: 10, p1:  8, m1:  2, m2: 67, t1:  0, t2: 12, p2:  0
# 			 Total:100 					  141 / 3000 completed
#
# read:586, recent:58 	 mode: recent
# fr:100%, mr: 69% 	 f1:  7, f2: 92, p1:  0, m1:  0, m2:  1, t1:  0, t2:  0, p2:  0
# 			 Total:100 					  142 / 3000 completed
#
# read:575, recent:28 	 mode: recent
# fr: 86%, mr: 50% 	 f1:  3, f2: 71, p1:  2, m1:  0, m2: 10, t1:  0, t2:  7, p2:  7
# 			 Total:100 					  143 / 3000 completed
#
# read:231, recent:17 	 mode: recent
# fr:  0%, mr: 65% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 75, t1:  0, t2: 15, p2:  0
# 			 Total:100 					  144 / 3000 completed
#
# read:3, recent:3 	 mode: else
# fr:  0%, mr:100% 	 f1:  0, f2:  0, p1: 10, m1:  1, m2: 62, t1:  0, t2: 27, p2:  0
# 			 Total:100 					  145 / 3000 completed
#
# read:19, recent:10 	 mode: recent
# fr: 40%, mr: 40% 	 f1:  1, f2:  7, p1:  9, m1:  1, m2: 20, t1:  0, t2: 62, p2:  0
# 			 Total:100 					  146 / 3000 completed
#
# read:11, recent:11 	 mode: recent
# fr: 91%, mr: 73% 	 f1:  2, f2: 27, p1:  7, m1:  0, m2:  0, t1:  0, t2: 21, p2: 43
# 			 Total:100 					  147 / 3000 completed
#
# read:700, recent:87 	 mode: recent
# fr: 87%, mr: 17% 	 f1:  6, f2: 73, p1:  2, m1:  1, m2: 13, t1:  0, t2:  5, p2:  0
# 			 Total:100 					  148 / 3000 completed
#
# read:264, recent:53 	 mode: recent
# fr:  0%, mr: 57% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 62, t1:  0, t2: 28, p2:  0
# 			 Total:100 					  149 / 3000 completed
#
# read:318, recent:70 	 mode: recent
# fr:  0%, mr: 41% 	 f1:  0, f2:  0, p1: 10, m1:  2, m2: 44, t1:  0, t2: 44, p2:  0
# 			 Total:100 					  150 / 3000 completed
#
# read:7, recent:5 	 mode: else
# fr: 56%, mr: 71% 	 f1:  0, f2: 14, p1:  8, m1:  0, m2: 15, t1:  0, t2: 14, p2: 49
# 			 Total:100 					  151 / 3000 completed
#
# read:1101, recent:51 	 mode: recent
# fr: 71%, mr: 47% 	 f1:  1, f2: 77, p1:  2, m1:  0, m2:  4, t1:  0, t2: 16, p2:  0
# 			 Total:100 					  152 / 3000 completed
#
# read:0, recent:0 	 mode: else
# fr:  0%, mr:  0% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2:  0, t1:  0, t2:  0, p2: 90
# 			 Total:100 					  153 / 3000 completed
#
# read:1299, recent:30 	 mode: recent
# fr:100%, mr: 30% 	 f1:  0, f2: 26, p1:  7, m1:  0, m2: 12, t1:  0, t2: 55, p2:  0
# 			 Total:100 					  154 / 3000 completed
#
# read:143, recent:28 	 mode: recent
# fr: 68%, mr: 46% 	 f1: 10, f2: 90, p1:  0, m1:  0, m2:  0, t1:  0, t2:  0, p2:  0
# 			 Total:100 					  155 / 3000 completed
#
# read:27, recent:27 	 mode: recent
# fr: 22%, mr: 74% 	 f1:  0, f2: 24, p1:  7, m1:  0, m2: 48, t1:  0, t2: 21, p2:  0
# 			 Total:100 					  156 / 3000 completed
#
# read:2801, recent:313 	 mode: recent
# fr: 82%, mr: 31% 	 f1:  1, f2: 60, p1:  3, m1:  0, m2: 14, t1:  0, t2: 22, p2:  0
# 			 Total:100 					  157 / 3000 completed
#
# read:0, recent:0 	 mode: else
# fr:  0%, mr:  0% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2:  0, t1:  0, t2:  0, p2: 90
# 			 Total:100 					  158 / 3000 completed
#
# read:97, recent:32 	 mode: recent
# fr: 25%, mr: 25% 	 f1:  1, f2: 59, p1:  4, m1:  0, m2: 33, t1:  0, t2:  3, p2:  0
# 			 Total:100 					  159 / 3000 completed
#
# read:415, recent:292 	 mode: recent
# fr: 11%, mr: 47% 	 f1:  2, f2: 67, p1:  3, m1:  0, m2:  0, t1:  0, t2: 28, p2:  0
# 			 Total:100 					  160 / 3000 completed
#
# read:563, recent:50 	 mode: recent
# fr: 10%, mr: 56% 	 f1:  1, f2:  9, p1:  9, m1:  5, m2: 56, t1:  0, t2: 20, p2:  0
# 			 Total:100 					  161 / 3000 completed
#
# read:0, recent:0 	 mode: else
# fr:  0%, mr:  0% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2:  0, t1:  0, t2:  0, p2: 90
# 			 Total:100 					  162 / 3000 completed
#
# read:2639, recent:256 	 mode: recent
# fr: 44%, mr: 28% 	 f1:  3, f2: 82, p1:  1, m1:  0, m2:  3, t1:  0, t2: 11, p2:  0
# 			 Total:100 					  163 / 3000 completed
#
# read:1843, recent:314 	 mode: recent
# fr: 34%, mr: 41% 	 f1:  0, f2: 66, p1:  3, m1:  0, m2:  4, t1:  0, t2: 27, p2:  0
# 			 Total:100 					  164 / 3000 completed
#
# read:14, recent:2 	 mode: else
# fr:  0%, mr: 64% 	 f1:  0, f2:  0, p1: 10, m1:  1, m2: 70, t1:  0, t2: 19, p2:  0
# 			 Total:100 					  165 / 3000 completed
#
# read:28, recent:4 	 mode: read
# fr: 14%, mr: 68% 	 f1:  1, f2: 98, p1:  0, m1:  0, m2:  0, t1:  0, t2:  1, p2:  0
# 			 Total:100 					  166 / 3000 completed
#
# read:657, recent:133 	 mode: recent
# fr:  0%, mr: 56% 	 f1:  0, f2:  0, p1: 10, m1:  1, m2: 79, t1:  0, t2: 10, p2:  0
# 			 Total:100 					  167 / 3000 completed
#
# read:142, recent:12 	 mode: recent
# fr: 92%, mr: 67% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 24, t1:  0, t2: 61, p2:  5
# 			 Total:100 					  168 / 3000 completed
#
# read:109, recent:77 	 mode: recent
# fr:  0%, mr: 64% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 55, t1:  0, t2: 35, p2:  0
# 			 Total:100 					  169 / 3000 completed
#
# read:677, recent:11 	 mode: recent
# fr:  0%, mr: 64% 	 f1:  0, f2:  0, p1: 10, m1:  1, m2: 52, t1:  0, t2: 37, p2:  0
# 			 Total:100 					  170 / 3000 completed
#
# read:73, recent:17 	 mode: recent
# fr: 88%, mr:  0% 	 f1:  1, f2: 15, p1:  8, m1:  0, m2:  0, t1:  0, t2: 76, p2:  0
# 			 Total:100 					  171 / 3000 completed
#
# read:975, recent:70 	 mode: recent
# fr: 34%, mr: 63% 	 f1:  5, f2: 83, p1:  1, m1:  0, m2:  1, t1:  0, t2: 10, p2:  0
# 			 Total:100 					  172 / 3000 completed
#
# read:213, recent:54 	 mode: recent
# fr: 19%, mr: 70% 	 f1:  0, f2: 12, p1:  8, m1:  2, m2: 74, t1:  0, t2:  4, p2:  0
# 			 Total:100 					  173 / 3000 completed
#
# read:13, recent:13 	 mode: recent
# fr:  0%, mr: 62% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 81, t1:  0, t2:  9, p2:  0
# 			 Total:100 					  174 / 3000 completed
#
# read:1515, recent:168 	 mode: recent
# fr: 76%, mr: 28% 	 f1:  1, f2: 80, p1:  1, m1:  0, m2:  5, t1:  0, t2: 13, p2:  0
# 			 Total:100 					  175 / 3000 completed
#
# read:21, recent:21 	 mode: recent
# fr:  0%, mr: 67% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 46, t1:  0, t2: 44, p2:  0
# 			 Total:100 					  176 / 3000 completed
#
# read:506, recent:73 	 mode: recent
# fr:  3%, mr: 33% 	 f1:  1, f2:  4, p1:  9, m1:  1, m2: 74, t1:  0, t2: 11, p2:  0
# 			 Total:100 					  177 / 3000 completed
#
# read:13, recent:3 	 mode: else
# fr:  0%, mr: 15% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 47, t1:  0, t2: 43, p2:  0
# 			 Total:100 					  178 / 3000 completed
#
# read:203, recent:178 	 mode: recent
# fr:  0%, mr: 47% 	 f1:  0, f2:  0, p1: 10, m1:  1, m2: 83, t1:  0, t2:  6, p2:  0
# 			 Total:100 					  179 / 3000 completed
#
# read:949, recent:14 	 mode: recent
# fr: 21%, mr: 64% 	 f1:  1, f2: 32, p1:  6, m1:  0, m2: 54, t1:  0, t2:  7, p2:  0
# 			 Total:100 					  180 / 3000 completed
#
# read:280, recent:20 	 mode: recent
# fr: 65%, mr: 40% 	 f1:  0, f2: 27, p1:  7, m1:  0, m2: 29, t1:  0, t2:  7, p2: 30
# 			 Total:100 					  181 / 3000 completed
#
# read:74, recent:6 	 mode: read
# fr: 27%, mr: 61% 	 f1:  1, f2:  7, p1:  9, m1:  0, m2: 51, t1:  0, t2: 32, p2:  0
# 			 Total:100 					  182 / 3000 completed
#
# read:51, recent:7 	 mode: recent
# fr:  0%, mr:100% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 54, t1:  0, t2: 36, p2:  0
# 			 Total:100 					  183 / 3000 completed
#
# read:36, recent:36 	 mode: recent
# fr: 11%, mr: 28% 	 f1:  0, f2: 72, p1:  2, m1:  0, m2: 17, t1:  0, t2:  9, p2:  0
# 			 Total:100 					  184 / 3000 completed
#
# read:13, recent:4 	 mode: else
# fr:  0%, mr: 54% 	 f1:  0, f2:  0, p1: 10, m1:  1, m2: 50, t1:  0, t2: 39, p2:  0
# 			 Total:100 					  185 / 3000 completed
#
# read:18, recent:12 	 mode: recent
# fr:  0%, mr: 17% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 21, t1:  0, t2: 69, p2:  0
# 			 Total:100 					  186 / 3000 completed
#
# read:1488, recent:63 	 mode: recent
# fr:100%, mr: 46% 	 f1:  2, f2: 82, p1:  1, m1:  0, m2:  7, t1:  0, t2:  8, p2:  0
# 			 Total:100 					  187 / 3000 completed
#
# read:2, recent:2 	 mode: else
# fr: 50%, mr:100% 	 f1:  1, f2: 11, p1:  8, m1:  0, m2: 28, t1:  0, t2: 47, p2:  5
# 			 Total:100 					  188 / 3000 completed
#
# read:1, recent:1 	 mode: else
# fr:100%, mr:  0% 	 f1:  1, f2: 12, p1:  8, m1:  0, m2:  0, t1:  0, t2:  1, p2: 78
# 			 Total:100 					  189 / 3000 completed
#
# read:3, recent:3 	 mode: else
# fr:  0%, mr: 67% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 27, t1:  0, t2:  4, p2: 59
# 			 Total:100 					  190 / 3000 completed
#
# read:134, recent:35 	 mode: recent
# fr: 60%, mr: 49% 	 f1:  0, f2: 57, p1:  4, m1:  0, m2: 18, t1:  0, t2: 21, p2:  0
# 			 Total:100 					  191 / 3000 completed
#
# read:1, recent:1 	 mode: else
# fr:  0%, mr:100% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 35, t1:  0, t2:  1, p2: 54
# 			 Total:100 					  192 / 3000 completed
#
# read:57, recent:4 	 mode: read
# fr: 28%, mr: 56% 	 f1:  0, f2: 89, p1:  1, m1:  0, m2:  1, t1:  0, t2:  9, p2:  0
# 			 Total:100 					  193 / 3000 completed
#
# read:681, recent:83 	 mode: recent
# fr: 81%, mr: 28% 	 f1:  1, f2: 76, p1:  2, m1:  0, m2:  3, t1:  0, t2: 18, p2:  0
# 			 Total:100 					  194 / 3000 completed
#
# read:38, recent:7 	 mode: recent
# fr: 43%, mr: 43% 	 f1:  1, f2: 11, p1:  8, m1:  0, m2: 13, t1:  0, t2: 67, p2:  0
# 			 Total:100 					  195 / 3000 completed
#
# read:3, recent:1 	 mode: else
# fr: 67%, mr:100% 	 f1:  0, f2:  4, p1:  9, m1:  0, m2: 59, t1:  0, t2:  6, p2: 22
# 			 Total:100 					  196 / 3000 completed
#
# read:11, recent:11 	 mode: recent
# fr:  0%, mr: 82% 	 f1:  0, f2:  0, p1: 10, m1:  1, m2: 55, t1:  0, t2:  1, p2: 33
# 			 Total:100 					  197 / 3000 completed
#
# read:5, recent:5 	 mode: else
# fr: 60%, mr: 40% 	 f1:  0, f2: 12, p1:  8, m1:  0, m2: 25, t1:  0, t2:  1, p2: 54
# 			 Total:100 					  198 / 3000 completed
#
# read:176, recent:111 	 mode: recent
# fr:  2%, mr: 41% 	 f1:  1, f2:  9, p1:  9, m1:  0, m2: 49, t1:  0, t2: 32, p2:  0
# 			 Total:100 					  199 / 3000 completed
#
# read:37, recent:37 	 mode: recent
# fr: 78%, mr:  5% 	 f1:  1, f2: 15, p1:  8, m1:  0, m2: 47, t1:  0, t2:  3, p2: 26
# 			 Total:100 					  200 / 3000 completed
#
# read:108, recent:13 	 mode: recent
# fr: 31%, mr: 54% 	 f1:  1, f2: 13, p1:  8, m1:  0, m2: 36, t1:  0, t2: 28, p2: 14
# 			 Total:100 					  201 / 3000 completed
#
# read:45, recent:5 	 mode: read
# fr:  0%, mr: 69% 	 f1:  0, f2:  0, p1: 10, m1:  2, m2: 63, t1:  0, t2: 25, p2:  0
# 			 Total:100 					  202 / 3000 completed
#
# read:7, recent:7 	 mode: recent
# fr:  0%, mr: 86% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 81, t1:  0, t2:  9, p2:  0
# 			 Total:100 					  203 / 3000 completed
#
# read:3390, recent:775 	 mode: recent
# fr: 42%, mr: 35% 	 f1: 10, f2: 72, p1:  1, m1:  0, m2:  0, t1:  0, t2: 17, p2:  0
# 			 Total:100 					  204 / 3000 completed
#
# read:434, recent:165 	 mode: recent
# fr: 36%, mr: 36% 	 f1:  1, f2: 93, p1:  0, m1:  0, m2:  1, t1:  0, t2:  5, p2:  0
# 			 Total:100 					  205 / 3000 completed
#
# read:41, recent:27 	 mode: recent
# fr: 93%, mr: 33% 	 f1:  0, f2: 42, p1:  5, m1:  0, m2: 28, t1:  0, t2: 25, p2:  0
# 			 Total:100 					  206 / 3000 completed
#
# read:14, recent:13 	 mode: recent
# fr:  0%, mr: 77% 	 f1:  0, f2:  0, p1: 10, m1:  1, m2: 71, t1:  0, t2: 15, p2:  3
# 			 Total:100 					  207 / 3000 completed
#
# read:35, recent:1 	 mode: read
# fr:  0%, mr: 74% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 78, t1:  0, t2: 12, p2:  0
# 			 Total:100 					  208 / 3000 completed
#
# read:6445, recent:58 	 mode: recent
# fr:  7%, mr: 36% 	 f1:  1, f2:  9, p1:  9, m1:  2, m2: 40, t1:  0, t2: 39, p2:  0
# 			 Total:100 					  209 / 3000 completed
#
# read:10, recent:8 	 mode: recent
# fr: 62%, mr: 25% 	 f1:  0, f2:  3, p1:  9, m1:  0, m2: 71, t1:  0, t2: 17, p2:  0
# 			 Total:100 					  210 / 3000 completed
#
# read:2023, recent:319 	 mode: recent
# fr: 62%, mr: 27% 	 f1:  1, f2: 47, p1:  5, m1:  0, m2: 15, t1:  0, t2: 32, p2:  0
# 			 Total:100 					  211 / 3000 completed
#
# read:531, recent:72 	 mode: recent
# fr: 44%, mr: 60% 	 f1:  2, f2: 67, p1:  3, m1:  0, m2:  4, t1:  0, t2: 24, p2:  0
# 			 Total:100 					  212 / 3000 completed
#
# read:10, recent:9 	 mode: recent
# fr:  0%, mr: 56% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 48, t1:  0, t2: 29, p2: 13
# 			 Total:100 					  213 / 3000 completed
#
# read:838, recent:280 	 mode: recent
# fr: 55%, mr: 27% 	 f1:  1, f2: 79, p1:  2, m1:  0, m2:  4, t1:  0, t2: 14, p2:  0
# 			 Total:100 					  214 / 3000 completed
#
# read:466, recent:55 	 mode: recent
# fr: 35%, mr: 56% 	 f1:  1, f2: 31, p1:  6, m1:  1, m2: 35, t1:  0, t2: 26, p2:  0
# 			 Total:100 					  215 / 3000 completed
#
# read:7, recent:7 	 mode: recent
# fr:  0%, mr: 71% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 68, t1:  0, t2: 22, p2:  0
# 			 Total:100 					  216 / 3000 completed
#
# read:64, recent:22 	 mode: recent
# fr: 41%, mr: 36% 	 f1:  1, f2:  5, p1:  9, m1:  1, m2: 44, t1:  0, t2: 40, p2:  0
# 			 Total:100 					  217 / 3000 completed
#
# read:82, recent:11 	 mode: recent
# fr:100%, mr: 55% 	 f1:  0, f2: 15, p1:  8, m1:  0, m2:  0, t1:  0, t2: 24, p2: 53
# 			 Total:100 					  218 / 3000 completed
#
# read:1771, recent:139 	 mode: recent
# fr: 37%, mr: 31% 	 f1:  1, f2: 67, p1:  3, m1:  0, m2:  3, t1:  0, t2: 26, p2:  0
# 			 Total:100 					  219 / 3000 completed
#
# read:1534, recent:27 	 mode: recent
# fr: 44%, mr: 78% 	 f1:  1, f2: 88, p1:  1, m1:  0, m2:  0, t1:  0, t2: 10, p2:  0
# 			 Total:100 					  220 / 3000 completed
#
# read:21, recent:21 	 mode: recent
# fr:100%, mr: 48% 	 f1:  2, f2: 20, p1:  7, m1:  0, m2:  0, t1:  0, t2: 71, p2:  0
# 			 Total:100 					  221 / 3000 completed
#
# read:171, recent:36 	 mode: recent
# fr: 50%, mr: 53% 	 f1:  2, f2: 72, p1:  2, m1:  0, m2: 18, t1:  0, t2:  6, p2:  0
# 			 Total:100 					  222 / 3000 completed
#
# read:6, recent:6 	 mode: else
# fr:  0%, mr: 67% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 58, t1:  0, t2: 32, p2:  0
# 			 Total:100 					  223 / 3000 completed
#
# read:363, recent:82 	 mode: recent
# fr: 55%, mr: 48% 	 f1:  0, f2: 59, p1:  4, m1:  0, m2:  7, t1:  0, t2: 30, p2:  0
# 			 Total:100 					  224 / 3000 completed
#
# read:9, recent:6 	 mode: else
# fr: 11%, mr: 89% 	 f1:  0, f2:  6, p1:  9, m1:  0, m2: 60, t1:  0, t2: 25, p2:  0
# 			 Total:100 					  225 / 3000 completed
#
# read:3246, recent:118 	 mode: recent
# fr: 40%, mr: 47% 	 f1: 13, f2: 72, p1:  1, m1:  0, m2:  1, t1:  0, t2: 13, p2:  0
# 			 Total:100 					  226 / 3000 completed
#
# read:129, recent:12 	 mode: recent
# fr: 33%, mr: 42% 	 f1:  0, f2:  4, p1:  9, m1:  0, m2: 41, t1:  0, t2: 46, p2:  0
# 			 Total:100 					  227 / 3000 completed
#
# read:21, recent:21 	 mode: recent
# fr: 33%, mr: 76% 	 f1:  1, f2: 37, p1:  6, m1:  0, m2: 36, t1:  0, t2: 20, p2:  0
# 			 Total:100 					  228 / 3000 completed
#
# read:6467, recent:1962 	 mode: recent
# fr:  1%, mr: 36% 	 f1:  2, f2: 39, p1:  5, m1:  0, m2: 11, t1:  0, t2: 43, p2:  0
# 			 Total:100 					  229 / 3000 completed
#
# read:928, recent:229 	 mode: recent
# fr: 61%, mr: 35% 	 f1:  2, f2: 87, p1:  1, m1:  0, m2:  1, t1:  0, t2:  9, p2:  0
# 			 Total:100 					  230 / 3000 completed
#
# read:504, recent:40 	 mode: recent
# fr: 95%, mr:  3% 	 f1:  2, f2: 41, p1:  5, m1:  0, m2: 52, t1:  0, t2:  0, p2:  0
# 			 Total:100 					  231 / 3000 completed
#
# read:119, recent:14 	 mode: recent
# fr:100%, mr: 21% 	 f1:  1, f2: 16, p1:  8, m1:  0, m2: 72, t1:  0, t2:  3, p2:  0
# 			 Total:100 					  232 / 3000 completed
#
# read:183, recent:13 	 mode: recent
# fr: 77%, mr: 54% 	 f1:  1, f2: 20, p1:  7, m1:  0, m2: 20, t1:  0, t2: 52, p2:  0
# 			 Total:100 					  233 / 3000 completed
#
# read:0, recent:0 	 mode: else
# fr:  0%, mr:  0% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2:  0, t1:  0, t2:  0, p2: 90
# 			 Total:100 					  234 / 3000 completed
#
# read:44, recent:14 	 mode: recent
# fr: 14%, mr: 50% 	 f1:  0, f2: 36, p1:  6, m1:  1, m2: 53, t1:  0, t2:  4, p2:  0
# 			 Total:100 					  235 / 3000 completed
#
# read:249, recent:43 	 mode: recent
# fr: 65%, mr: 77% 	 f1:  2, f2: 21, p1:  7, m1:  0, m2: 65, t1:  0, t2:  5, p2:  0
# 			 Total:100 					  236 / 3000 completed
#
# read:36, recent:34 	 mode: recent
# fr:  0%, mr: 71% 	 f1:  0, f2:  0, p1: 10, m1:  3, m2: 72, t1:  0, t2: 15, p2:  0
# 			 Total:100 					  237 / 3000 completed
#
# read:0, recent:0 	 mode: else
# fr:  0%, mr:  0% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2:  0, t1:  0, t2:  0, p2: 90
# 			 Total:100 					  238 / 3000 completed
#
# read:14, recent:14 	 mode: recent
# fr: 43%, mr: 36% 	 f1:  2, f2: 51, p1:  4, m1:  0, m2: 29, t1:  0, t2: 14, p2:  0
# 			 Total:100 					  239 / 3000 completed
#
# read:75, recent:9 	 mode: recent
# fr:100%, mr: 78% 	 f1:  0, f2: 38, p1:  6, m1:  0, m2: 56, t1:  0, t2:  0, p2:  0
# 			 Total:100 					  240 / 3000 completed
#
# read:26, recent:26 	 mode: recent
# fr: 85%, mr: 15% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 89, t1:  0, t2:  1, p2:  0
# 			 Total:100 					  241 / 3000 completed
#
# read:13271, recent:2477 	 mode: recent
# fr:  9%, mr: 21% 	 f1:  2, f2: 36, p1:  6, m1:  0, m2:  5, t1:  0, t2: 51, p2:  0
# 			 Total:100 					  242 / 3000 completed
#
# read:826, recent:70 	 mode: recent
# fr: 96%, mr: 17% 	 f1:  0, f2: 20, p1:  8, m1:  0, m2: 17, t1:  0, t2: 31, p2: 24
# 			 Total:100 					  243 / 3000 completed
#
# read:224, recent:136 	 mode: recent
# fr:  4%, mr: 35% 	 f1:  1, f2: 10, p1:  8, m1:  0, m2: 52, t1:  0, t2: 29, p2:  0
# 			 Total:100 					  244 / 3000 completed
#
# read:44, recent:14 	 mode: recent
# fr:  0%, mr: 64% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 81, t1:  0, t2:  9, p2:  0
# 			 Total:100 					  245 / 3000 completed
#
# read:46, recent:17 	 mode: recent
# fr:  0%, mr: 24% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 68, t1:  0, t2:  9, p2: 13
# 			 Total:100 					  246 / 3000 completed
#
# read:0, recent:0 	 mode: else
# fr:  0%, mr:  0% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2:  0, t1:  0, t2:  0, p2: 90
# 			 Total:100 					  247 / 3000 completed
#
# read:500, recent:71 	 mode: recent
# fr: 11%, mr: 54% 	 f1:  1, f2: 18, p1:  8, m1:  1, m2: 44, t1:  0, t2: 28, p2:  0
# 			 Total:100 					  248 / 3000 completed
#
# read:13, recent:9 	 mode: recent
# fr:  0%, mr: 78% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 84, t1:  0, t2:  5, p2:  1
# 			 Total:100 					  249 / 3000 completed
#
# read:15, recent:15 	 mode: recent
# fr:  0%, mr: 87% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 77, t1:  0, t2: 13, p2:  0
# 			 Total:100 					  250 / 3000 completed
#
# read:278, recent:23 	 mode: recent
# fr:100%, mr: 26% 	 f1:  0, f2: 39, p1:  6, m1:  0, m2: 27, t1:  0, t2:  0, p2: 28
# 			 Total:100 					  251 / 3000 completed
#
# read:164, recent:68 	 mode: recent
# fr: 76%, mr: 22% 	 f1:  1, f2: 42, p1:  5, m1:  0, m2: 43, t1:  0, t2:  9, p2:  0
# 			 Total:100 					  252 / 3000 completed
#
# read:29, recent:22 	 mode: recent
# fr: 77%, mr: 86% 	 f1:  0, f2:  7, p1:  9, m1:  0, m2: 50, t1:  0, t2: 34, p2:  0
# 			 Total:100 					  253 / 3000 completed
#
# read:108, recent:25 	 mode: recent
# fr: 32%, mr: 64% 	 f1:  0, f2: 78, p1:  2, m1:  1, m2: 14, t1:  0, t2:  5, p2:  0
# 			 Total:100 					  254 / 3000 completed
#
# read:39, recent:5 	 mode: read
# fr: 74%, mr: 62% 	 f1:  1, f2: 51, p1:  4, m1:  0, m2: 10, t1:  0, t2: 34, p2:  0
# 			 Total:100 					  255 / 3000 completed
#
# read:269, recent:78 	 mode: recent
# fr: 28%, mr: 46% 	 f1:  1, f2: 60, p1:  3, m1:  0, m2: 36, t1:  0, t2:  0, p2:  0
# 			 Total:100 					  256 / 3000 completed
#
# read:184, recent:3 	 mode: read
# fr: 62%, mr: 74% 	 f1: 14, f2: 66, p1:  2, m1:  0, m2:  2, t1:  0, t2: 16, p2:  0
# 			 Total:100 					  257 / 3000 completed
#
# read:408, recent:293 	 mode: recent
# fr: 21%, mr: 44% 	 f1:  6, f2: 89, p1:  0, m1:  0, m2:  0, t1:  0, t2:  5, p2:  0
# 			 Total:100 					  258 / 3000 completed
#
# read:68, recent:41 	 mode: recent
# fr: 51%, mr: 49% 	 f1:  0, f2: 30, p1:  7, m1:  0, m2: 34, t1:  0, t2: 29, p2:  0
# 			 Total:100 					  259 / 3000 completed
#
# read:327, recent:28 	 mode: recent
# fr: 82%, mr: 79% 	 f1:  0, f2: 67, p1:  3, m1:  1, m2: 14, t1:  0, t2: 15, p2:  0
# 			 Total:100 					  260 / 3000 completed
#
# read:144, recent:54 	 mode: recent
# fr: 37%, mr: 46% 	 f1:  1, f2: 21, p1:  7, m1:  0, m2: 43, t1:  0, t2: 28, p2:  0
# 			 Total:100 					  261 / 3000 completed
#
# read:577, recent:107 	 mode: recent
# fr: 20%, mr: 61% 	 f1: 19, f2: 51, p1:  3, m1:  0, m2:  8, t1:  0, t2: 19, p2:  0
# 			 Total:100 					  262 / 3000 completed
#
# read:12, recent:5 	 mode: else
# fr: 83%, mr: 92% 	 f1:  0, f2: 35, p1:  6, m1:  0, m2: 21, t1:  0, t2: 38, p2:  0
# 			 Total:100 					  263 / 3000 completed
#
# read:23, recent:17 	 mode: recent
# fr:  0%, mr: 82% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 78, t1:  0, t2: 12, p2:  0
# 			 Total:100 					  264 / 3000 completed
#
# read:239, recent:13 	 mode: recent
# fr: 77%, mr: 23% 	 f1:  8, f2: 80, p1:  1, m1:  0, m2: 10, t1:  0, t2:  1, p2:  0
# 			 Total:100 					  265 / 3000 completed
#
# read:1307, recent:118 	 mode: recent
# fr: 96%, mr: 17% 	 f1:  0, f2: 26, p1:  7, m1:  0, m2: 13, t1:  0, t2: 54, p2:  0
# 			 Total:100 					  266 / 3000 completed
#
# read:250, recent:28 	 mode: recent
# fr: 64%, mr: 54% 	 f1:  1, f2: 35, p1:  6, m1:  0, m2: 33, t1:  0, t2: 25, p2:  0
# 			 Total:100 					  267 / 3000 completed
#
# read:2595, recent:29 	 mode: recent
# fr: 62%, mr: 48% 	 f1:  1, f2: 81, p1:  1, m1:  0, m2: 14, t1:  0, t2:  3, p2:  0
# 			 Total:100 					  268 / 3000 completed
#
# read:184, recent:34 	 mode: recent
# fr:  0%, mr: 24% 	 f1:  0, f2:  0, p1: 10, m1:  1, m2: 79, t1:  0, t2: 10, p2:  0
# 			 Total:100 					  269 / 3000 completed
#
# read:96, recent:25 	 mode: recent
# fr:  0%, mr: 68% 	 f1:  0, f2:  0, p1: 10, m1:  1, m2: 71, t1:  0, t2: 18, p2:  0
# 			 Total:100 					  270 / 3000 completed
#
# read:40, recent:15 	 mode: recent
# fr: 47%, mr: 80% 	 f1:  1, f2: 15, p1:  8, m1:  2, m2: 39, t1:  0, t2: 35, p2:  0
# 			 Total:100 					  271 / 3000 completed
#
# read:270, recent:24 	 mode: recent
# fr: 96%, mr: 83% 	 f1:  0, f2: 78, p1:  2, m1:  0, m2: 11, t1:  0, t2:  9, p2:  0
# 			 Total:100 					  272 / 3000 completed
#
# read:28, recent:28 	 mode: recent
# fr:100%, mr: 54% 	 f1:  1, f2: 40, p1:  5, m1:  0, m2:  0, t1:  0, t2: 54, p2:  0
# 			 Total:100 					  273 / 3000 completed
#
# read:1181, recent:94 	 mode: recent
# fr:  1%, mr: 41% 	 f1:  3, f2: 97, p1:  0, m1:  0, m2:  0, t1:  0, t2:  0, p2:  0
# 			 Total:100 					  274 / 3000 completed
#
# read:1760, recent:112 	 mode: recent
# fr: 98%, mr: 28% 	 f1:  0, f2: 71, p1:  2, m1:  0, m2: 17, t1:  0, t2: 10, p2:  0
# 			 Total:100 					  275 / 3000 completed
#
# read:617, recent:100 	 mode: recent
# fr:  1%, mr: 56% 	 f1:  1, f2:  7, p1:  9, m1:  1, m2: 60, t1:  0, t2: 22, p2:  0
# 			 Total:100 					  276 / 3000 completed
#
# read:121, recent:58 	 mode: recent
# fr:  2%, mr: 79% 	 f1:  1, f2: 10, p1:  8, m1:  0, m2: 22, t1:  0, t2: 12, p2: 47
# 			 Total:100 					  277 / 3000 completed
#
# read:307, recent:51 	 mode: recent
# fr: 55%, mr: 28% 	 f1:  2, f2: 67, p1:  3, m1:  0, m2: 18, t1:  0, t2: 10, p2:  0
# 			 Total:100 					  278 / 3000 completed
#
# read:1, recent:1 	 mode: else
# fr:  0%, mr:100% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2:  4, t1:  0, t2:  0, p2: 86
# 			 Total:100 					  279 / 3000 completed
#
# read:447, recent:6 	 mode: read
# fr: 40%, mr: 59% 	 f1:  2, f2: 27, p1:  7, m1:  0, m2: 12, t1:  0, t2: 52, p2:  0
# 			 Total:100 					  280 / 3000 completed
#
# read:47, recent:47 	 mode: recent
# fr: 36%, mr: 64% 	 f1:  1, f2: 38, p1:  6, m1:  0, m2: 33, t1:  0, t2: 20, p2:  2
# 			 Total:100 					  281 / 3000 completed
#
# read:6, recent:6 	 mode: else
# fr:  0%, mr:100% 	 f1:  0, f2:  0, p1: 10, m1:  7, m2: 78, t1:  0, t2:  5, p2:  0
# 			 Total:100 					  282 / 3000 completed
#
# read:110, recent:53 	 mode: recent
# fr: 40%, mr: 21% 	 f1:  0, f2: 10, p1:  9, m1:  1, m2: 65, t1:  0, t2: 15, p2:  0
# 			 Total:100 					  283 / 3000 completed
#
# read:135, recent:53 	 mode: recent
# fr:  4%, mr: 55% 	 f1:  0, f2: 34, p1:  6, m1:  0, m2: 58, t1:  0, t2:  2, p2:  0
# 			 Total:100 					  284 / 3000 completed
#
# read:41, recent:5 	 mode: read
# fr: 10%, mr: 83% 	 f1:  0, f2: 19, p1:  8, m1:  2, m2: 63, t1:  0, t2:  8, p2:  0
# 			 Total:100 					  285 / 3000 completed
#
# read:1237, recent:306 	 mode: recent
# fr:  2%, mr: 32% 	 f1:  1, f2:  8, p1:  9, m1:  1, m2: 13, t1:  0, t2: 68, p2:  0
# 			 Total:100 					  286 / 3000 completed
#
# read:5, recent:5 	 mode: else
# fr:  0%, mr: 60% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 72, t1:  0, t2: 18, p2:  0
# 			 Total:100 					  287 / 3000 completed
#
# read:305, recent:286 	 mode: recent
# fr:100%, mr: 42% 	 f1:  0, f2: 87, p1:  1, m1:  0, m2:  1, t1:  0, t2: 11, p2:  0
# 			 Total:100 					  288 / 3000 completed
#
# read:98, recent:41 	 mode: recent
# fr: 98%, mr: 63% 	 f1: 10, f2: 90, p1:  0, m1:  0, m2:  0, t1:  0, t2:  0, p2:  0
# 			 Total:100 					  289 / 3000 completed
#
# read:453, recent:3 	 mode: read
# fr: 25%, mr: 60% 	 f1:  1, f2: 63, p1:  3, m1:  0, m2:  0, t1:  0, t2: 33, p2:  0
# 			 Total:100 					  290 / 3000 completed
#
# read:29, recent:2 	 mode: read
# fr: 90%, mr: 45% 	 f1:  1, f2: 54, p1:  4, m1:  0, m2: 27, t1:  0, t2: 14, p2:  0
# 			 Total:100 					  291 / 3000 completed
#
# read:120, recent:21 	 mode: recent
# fr: 48%, mr: 81% 	 f1:  1, f2: 31, p1:  6, m1:  0, m2: 56, t1:  0, t2:  6, p2:  0
# 			 Total:100 					  292 / 3000 completed
#
# read:0, recent:0 	 mode: else
# fr:  0%, mr:  0% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2:  0, t1:  0, t2:  0, p2: 90
# 			 Total:100 					  293 / 3000 completed
#
# read:65, recent:5 	 mode: read
# fr:  2%, mr: 60% 	 f1:  0, f2:  0, p1: 10, m1:  1, m2: 79, t1:  0, t2: 10, p2:  0
# 			 Total:100 					  294 / 3000 completed
#
# read:15, recent:15 	 mode: recent
# fr: 73%, mr: 33% 	 f1:  1, f2: 13, p1:  8, m1:  1, m2: 39, t1:  0, t2:  5, p2: 33
# 			 Total:100 					  295 / 3000 completed
#
# read:649, recent:48 	 mode: recent
# fr:  0%, mr: 50% 	 f1:  0, f2:  0, p1: 10, m1:  1, m2: 69, t1:  0, t2: 20, p2:  0
# 			 Total:100 					  296 / 3000 completed
#
# read:393, recent:242 	 mode: recent
# fr:  2%, mr: 19% 	 f1:  3, f2: 58, p1:  3, m1:  0, m2:  3, t1:  0, t2: 33, p2:  0
# 			 Total:100 					  297 / 3000 completed
#
# read:391, recent:80 	 mode: recent
# fr:  4%, mr: 40% 	 f1:  1, f2: 16, p1:  8, m1:  2, m2: 63, t1:  0, t2: 10, p2:  0
# 			 Total:100 					  298 / 3000 completed
#
# read:203, recent:31 	 mode: recent
# fr:  3%, mr: 68% 	 f1:  0, f2: 24, p1:  7, m1:  4, m2: 49, t1:  0, t2: 16, p2:  0
# 			 Total:100 					  299 / 3000 completed
#
# read:804, recent:100 	 mode: recent
# fr:100%, mr: 37% 	 f1:  5, f2: 95, p1:  0, m1:  0, m2:  0, t1:  0, t2:  0, p2:  0
# ...
# 			 Total:100 					  692 / 3000 completed
#
# read:796, recent:52 	 mode: recent
# fr:  6%, mr: 48% 	 f1:  0, f2:100, p1:  0, m1:  0, m2:  0, t1:  0, t2:  0, p2:  0
# 			 Total:100 					  693 / 3000 completed
#
# read:106, recent:106 	 mode: recent
# fr: 63%, mr: 18% 	 f1:  1, f2: 33, p1:  6, m1:  1, m2: 43, t1:  0, t2: 16, p2:  0
# 			 Total:100 					  694 / 3000 completed
#
# read:31, recent:31 	 mode: recent
# fr: 55%, mr: 84% 	 f1:  0, f2: 18, p1:  8, m1:  0, m2: 45, t1:  0, t2: 18, p2: 11
# 			 Total:100 					  695 / 3000 completed
#
# read:16, recent:0 	 mode: else
# fr: 50%, mr: 50% 	 f1:  1, f2: 26, p1:  7, m1:  0, m2: 60, t1:  0, t2:  6, p2:  0
# 			 Total:100 					  696 / 3000 completed
#
# read:20, recent:0 	 mode: else
# fr: 60%, mr: 35% 	 f1:  0, f2: 17, p1:  8, m1:  0, m2: 46, t1:  0, t2: 29, p2:  0
# 			 Total:100 					  697 / 3000 completed
#
# read:483, recent:18 	 mode: recent
# fr:100%, mr:  0% 	 f1:  4, f2: 96, p1:  0, m1:  0, m2:  0, t1:  0, t2:  0, p2:  0
# 			 Total:100 					  698 / 3000 completed
#
# read:1381, recent:156 	 mode: recent
# fr: 88%, mr: 20% 	 f1:  1, f2: 93, p1:  0, m1:  0, m2:  2, t1:  0, t2:  4, p2:  0
# 			 Total:100 					  699 / 3000 completed
#
# read:17, recent:10 	 mode: recent
# fr:  0%, mr: 70% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 56, t1:  0, t2: 21, p2: 13
# 			 Total:100 					  700 / 3000 completed
#
# read:127, recent:3 	 mode: read
# fr: 49%, mr: 55% 	 f1:  2, f2: 61, p1:  3, m1:  0, m2:  5, t1:  0, t2: 29, p2:  0
# 			 Total:100 					  701 / 3000 completed
#
# read:418, recent:69 	 mode: recent
# fr: 35%, mr: 43% 	 f1:  4, f2: 81, p1:  1, m1:  0, m2:  0, t1:  0, t2: 14, p2:  0
# 			 Total:100 					  702 / 3000 completed
#
# read:6, recent:4 	 mode: else
# fr:100%, mr: 83% 	 f1:  0, f2: 12, p1:  8, m1:  0, m2:  3, t1:  0, t2:  5, p2: 72
# 			 Total:100 					  703 / 3000 completed
#
# read:623, recent:406 	 mode: recent
# fr: 31%, mr: 24% 	 f1:  2, f2:  6, p1:  9, m1:  2, m2: 36, t1:  0, t2: 45, p2:  0
# 			 Total:100 					  704 / 3000 completed
#
# read:958, recent:231 	 mode: recent
# fr:  0%, mr: 42% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 17, t1:  0, t2: 54, p2: 19
# 			 Total:100 					  705 / 3000 completed
#
# read:15, recent:8 	 mode: recent
# fr:  0%, mr: 75% 	 f1:  0, f2:  0, p1: 10, m1:  2, m2: 37, t1:  0, t2: 49, p2:  2
# 			 Total:100 					  706 / 3000 completed
#
# read:1236, recent:161 	 mode: recent
# fr: 96%, mr: 43% 	 f1: 10, f2: 64, p1:  2, m1:  0, m2:  1, t1:  0, t2: 23, p2:  0
# 			 Total:100 					  707 / 3000 completed
#
# read:273, recent:273 	 mode: recent
# fr: 40%, mr: 32% 	 f1:  2, f2: 46, p1:  5, m1:  0, m2: 20, t1:  0, t2: 27, p2:  0
# 			 Total:100 					  708 / 3000 completed
#
# read:37, recent:6 	 mode: read
# fr: 27%, mr: 54% 	 f1:  0, f2: 15, p1:  8, m1:  0, m2: 60, t1:  0, t2: 17, p2:  0
# 			 Total:100 					  709 / 3000 completed
#
# read:1342, recent:266 	 mode: recent
# fr: 62%, mr: 28% 	 f1:  7, f2: 77, p1:  1, m1:  0, m2:  1, t1:  0, t2: 14, p2:  0
# 			 Total:100 					  710 / 3000 completed
#
# read:198, recent:55 	 mode: recent
# fr: 96%, mr: 35% 	 f1:  0, f2: 20, p1:  8, m1:  0, m2: 13, t1:  0, t2: 48, p2: 11
# 			 Total:100 					  711 / 3000 completed
#
# read:235, recent:61 	 mode: recent
# fr: 13%, mr: 34% 	 f1:  1, f2: 84, p1:  1, m1:  0, m2:  3, t1:  0, t2: 11, p2:  0
# 			 Total:100 					  712 / 3000 completed
#
# read:1241, recent:63 	 mode: recent
# fr: 87%, mr: 28% 	 f1:  3, f2: 80, p1:  1, m1:  0, m2:  3, t1:  0, t2: 12, p2:  1
# 			 Total:100 					  713 / 3000 completed
#
# read:7, recent:7 	 mode: recent
# fr: 28%, mr: 71% 	 f1:  1, f2: 17, p1:  8, m1:  0, m2: 50, t1:  0, t2: 24, p2:  0
# 			 Total:100 					  714 / 3000 completed
#
# read:0, recent:0 	 mode: else
# fr:  0%, mr:  0% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2:  0, t1:  0, t2:  0, p2: 90
# 			 Total:100 					  715 / 3000 completed
#
# read:844, recent:299 	 mode: recent
# fr: 27%, mr: 36% 	 f1:  2, f2: 79, p1:  1, m1:  0, m2:  0, t1:  0, t2: 18, p2:  0
# 			 Total:100 					  716 / 3000 completed
#
# read:39, recent:1 	 mode: read
# fr: 15%, mr: 69% 	 f1:  1, f2: 10, p1:  8, m1:  2, m2: 57, t1:  0, t2:  1, p2: 21
# 			 Total:100 					  717 / 3000 completed
#
# read:2539, recent:453 	 mode: recent
# fr: 76%, mr: 23% 	 f1:  2, f2: 48, p1:  5, m1:  0, m2: 15, t1:  0, t2: 30, p2:  0
# 			 Total:100 					  718 / 3000 completed
#
# read:153, recent:64 	 mode: recent
# fr:  8%, mr: 50% 	 f1:  2, f2: 27, p1:  7, m1:  0, m2: 60, t1:  0, t2:  4, p2:  0
# 			 Total:100 					  719 / 3000 completed
#
# read:62, recent:41 	 mode: recent
# fr: 44%, mr: 39% 	 f1:  1, f2:  7, p1:  9, m1:  0, m2: 60, t1:  0, t2: 23, p2:  0
# 			 Total:100 					  720 / 3000 completed
#
# read:538, recent:85 	 mode: recent
# fr:  7%, mr: 28% 	 f1:  2, f2: 32, p1:  6, m1:  1, m2: 46, t1:  0, t2: 13, p2:  0
# 			 Total:100 					  721 / 3000 completed
#
# read:28, recent:13 	 mode: recent
# fr:  0%, mr: 69% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 68, t1:  0, t2: 22, p2:  0
# 			 Total:100 					  722 / 3000 completed
#
# read:0, recent:0 	 mode: else
# fr:  0%, mr:  0% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2:  0, t1:  0, t2:  0, p2: 90
# 			 Total:100 					  723 / 3000 completed
#
# read:2375, recent:395 	 mode: recent
# fr: 35%, mr: 31% 	 f1:  3, f2: 44, p1:  5, m1:  0, m2: 14, t1:  0, t2: 34, p2:  0
# 			 Total:100 					  724 / 3000 completed
#
# read:783, recent:410 	 mode: recent
# fr:  0%, mr: 38% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 44, t1:  0, t2: 46, p2:  0
# 			 Total:100 					  725 / 3000 completed
#
# read:1718, recent:614 	 mode: recent
# fr: 33%, mr: 39% 	 f1:  3, f2: 70, p1:  2, m1:  0, m2:  2, t1:  0, t2:  9, p2: 14
# 			 Total:100 					  726 / 3000 completed
#
# read:111, recent:46 	 mode: recent
# fr: 61%, mr: 41% 	 f1:  1, f2: 23, p1:  7, m1:  0, m2: 41, t1:  0, t2: 28, p2:  0
# 			 Total:100 					  727 / 3000 completed
#
# read:39, recent:21 	 mode: recent
# fr:  0%, mr: 76% 	 f1:  0, f2:  0, p1: 10, m1:  2, m2: 73, t1:  0, t2: 15, p2:  0
# 			 Total:100 					  728 / 3000 completed
#
# read:27, recent:4 	 mode: read
# fr:  7%, mr: 41% 	 f1:  1, f2: 60, p1:  3, m1:  0, m2: 30, t1:  0, t2:  6, p2:  0
# 			 Total:100 					  729 / 3000 completed
#
# read:18, recent:11 	 mode: recent
# fr:  0%, mr: 55% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 53, t1:  0, t2: 37, p2:  0
# 			 Total:100 					  730 / 3000 completed
#
# read:322, recent:38 	 mode: recent
# fr: 39%, mr: 47% 	 f1:  0, f2: 28, p1:  7, m1:  0, m2: 47, t1:  0, t2: 18, p2:  0
# 			 Total:100 					  731 / 3000 completed
#
# read:721, recent:104 	 mode: recent
# fr:  4%, mr: 46% 	 f1:  1, f2: 10, p1:  8, m1:  0, m2: 50, t1:  0, t2: 31, p2:  0
# 			 Total:100 					  732 / 3000 completed
#
# read:32, recent:28 	 mode: recent
# fr: 61%, mr: 46% 	 f1:  0, f2: 20, p1:  8, m1:  2, m2: 37, t1:  0, t2:  7, p2: 26
# 			 Total:100 					  733 / 3000 completed
#
# read:250, recent:164 	 mode: recent
# fr: 26%, mr: 48% 	 f1:  1, f2: 49, p1:  5, m1:  0, m2:  6, t1:  0, t2:  5, p2: 34
# 			 Total:100 					  734 / 3000 completed
#
# read:3, recent:1 	 mode: else
# fr:  0%, mr: 67% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 52, t1:  0, t2:  5, p2: 33
# 			 Total:100 					  735 / 3000 completed
#
# read:744, recent:95 	 mode: recent
# fr: 41%, mr: 37% 	 f1:  2, f2: 78, p1:  2, m1:  1, m2:  4, t1:  0, t2: 13, p2:  0
# 			 Total:100 					  736 / 3000 completed
#
# read:39, recent:28 	 mode: recent
# fr: 93%, mr:  7% 	 f1:  1, f2:  1, p1:  9, m1:  0, m2: 49, t1:  0, t2:  5, p2: 35
# 			 Total:100 					  737 / 3000 completed
#
# read:2, recent:2 	 mode: else
# fr:  0%, mr:  0% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2:  0, t1:  0, t2: 54, p2: 36
# 			 Total:100 					  738 / 3000 completed
#
# read:574, recent:34 	 mode: recent
# fr: 18%, mr: 68% 	 f1:  0, f2: 53, p1:  4, m1:  0, m2: 21, t1:  0, t2: 22, p2:  0
# 			 Total:100 					  739 / 3000 completed
#
# read:0, recent:0 	 mode: else
# fr:  0%, mr:  0% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2:  0, t1:  0, t2:  0, p2: 90
# 			 Total:100 					  740 / 3000 completed
#
# read:502, recent:141 	 mode: recent
# fr:  6%, mr: 35% 	 f1:  2, f2: 31, p1:  6, m1:  0, m2: 48, t1:  0, t2: 13, p2:  0
# 			 Total:100 					  741 / 3000 completed
#
# read:32, recent:1 	 mode: read
# fr:  0%, mr: 84% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 81, t1:  0, t2:  9, p2:  0
# 			 Total:100 					  742 / 3000 completed
#
# read:653, recent:179 	 mode: recent
# fr: 24%, mr: 56% 	 f1:  6, f2: 68, p1:  2, m1:  0, m2:  2, t1:  0, t2: 22, p2:  0
# 			 Total:100 					  743 / 3000 completed
#
# read:222, recent:118 	 mode: recent
# fr: 98%, mr:  2% 	 f1:  0, f2:  8, p1:  9, m1:  0, m2: 47, t1:  0, t2: 36, p2:  0
# 			 Total:100 					  744 / 3000 completed
#
# read:46, recent:16 	 mode: recent
# fr:  0%, mr: 75% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 78, t1:  0, t2: 12, p2:  0
# 			 Total:100 					  745 / 3000 completed
#
# read:1588, recent:162 	 mode: recent
# fr: 38%, mr: 23% 	 f1:  0, f2: 64, p1:  3, m1:  0, m2: 14, t1:  0, t2: 19, p2:  0
# 			 Total:100 					  746 / 3000 completed
#
# read:4204, recent:1644 	 mode: recent
# fr:  1%, mr: 39% 	 f1:  1, f2:  3, p1:  9, m1:  0, m2:  4, t1:  0, t2: 83, p2:  0
# 			 Total:100 					  747 / 3000 completed
#
# read:63, recent:0 	 mode: read
# fr: 56%, mr: 56% 	 f1: 14, f2: 58, p1:  2, m1:  0, m2: 13, t1:  0, t2: 10, p2:  3
# 			 Total:100 					  748 / 3000 completed
#
# read:10, recent:5 	 mode: else
# fr: 40%, mr: 70% 	 f1:  0, f2: 27, p1:  7, m1:  1, m2: 48, t1:  0, t2: 17, p2:  0
# 			 Total:100 					  749 / 3000 completed
#
# read:44, recent:2 	 mode: read
# fr:  9%, mr: 66% 	 f1:  0, f2: 41, p1:  5, m1:  0, m2: 30, t1:  0, t2: 24, p2:  0
# 			 Total:100 					  750 / 3000 completed
#
# read:110, recent:22 	 mode: recent
# fr: 18%, mr: 77% 	 f1:  0, f2: 62, p1:  3, m1:  0, m2: 34, t1:  0, t2:  1, p2:  0
# 			 Total:100 					  751 / 3000 completed
#
# read:320, recent:24 	 mode: recent
# fr: 83%, mr: 33% 	 f1:  0, f2: 24, p1:  7, m1:  0, m2: 48, t1:  0, t2:  5, p2: 16
# 			 Total:100 					  752 / 3000 completed
#
# read:128, recent:3 	 mode: read
# fr: 41%, mr: 63% 	 f1:  1, f2: 62, p1:  3, m1:  0, m2: 13, t1:  0, t2: 21, p2:  0
# 			 Total:100 					  753 / 3000 completed
#
# read:2950, recent:323 	 mode: recent
# fr: 80%, mr: 43% 	 f1:  3, f2: 77, p1:  2, m1:  0, m2:  1, t1:  0, t2: 17, p2:  0
# 			 Total:100 					  754 / 3000 completed
#
# read:64, recent:63 	 mode: recent
# fr: 98%, mr: 32% 	 f1:  0, f2: 31, p1:  6, m1:  0, m2: 28, t1:  0, t2: 35, p2:  0
# 			 Total:100 					  755 / 3000 completed
#
# read:92, recent:92 	 mode: recent
# fr: 34%, mr: 42% 	 f1:  2, f2: 95, p1:  0, m1:  0, m2:  0, t1:  0, t2:  3, p2:  0
# 			 Total:100 					  756 / 3000 completed
#
# read:4049, recent:174 	 mode: recent
# fr:  9%, mr: 43% 	 f1:  2, f2:  7, p1:  9, m1:  0, m2: 75, t1:  0, t2:  7, p2:  0
# 			 Total:100 					  757 / 3000 completed
#
# read:521, recent:98 	 mode: recent
# fr: 20%, mr: 40% 	 f1:  0, f2: 11, p1:  8, m1:  3, m2: 66, t1:  0, t2: 12, p2:  0
# 			 Total:100 					  758 / 3000 completed
#
# read:209, recent:27 	 mode: recent
# fr: 93%, mr: 19% 	 f1:  1, f2: 36, p1:  6, m1:  0, m2: 11, t1:  0, t2:  2, p2: 44
# 			 Total:100 					  759 / 3000 completed
#
# read:2446, recent:180 	 mode: recent
# fr: 28%, mr: 44% 	 f1:  1, f2: 56, p1:  4, m1:  0, m2:  3, t1:  0, t2: 36, p2:  0
# 			 Total:100 					  760 / 3000 completed
#
# read:29, recent:18 	 mode: recent
# fr:  0%, mr: 83% 	 f1:  0, f2:  0, p1: 10, m1:  1, m2: 73, t1:  0, t2: 16, p2:  0
# 			 Total:100 					  761 / 3000 completed
#
# read:3681, recent:198 	 mode: recent
# fr: 10%, mr: 44% 	 f1: 14, f2: 66, p1:  2, m1:  0, m2:  0, t1:  0, t2: 18, p2:  0
# 			 Total:100 					  762 / 3000 completed
#
# read:19, recent:7 	 mode: recent
# fr:  0%, mr:100% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 77, t1:  0, t2: 13, p2:  0
# 			 Total:100 					  763 / 3000 completed
#
# read:4659, recent:379 	 mode: recent
# fr: 81%, mr: 36% 	 f1:  1, f2: 59, p1:  4, m1:  0, m2:  4, t1:  0, t2: 32, p2:  0
# 			 Total:100 					  764 / 3000 completed
#
# read:464, recent:18 	 mode: recent
# fr:100%, mr: 28% 	 f1:  0, f2: 35, p1:  6, m1:  0, m2:  9, t1:  0, t2: 50, p2:  0
# 			 Total:100 					  765 / 3000 completed
#
# read:466, recent:104 	 mode: recent
# fr:  0%, mr: 56% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 66, t1:  0, t2: 24, p2:  0
# 			 Total:100 					  766 / 3000 completed
#
# read:3, recent:3 	 mode: else
# fr:  0%, mr: 33% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2:  5, t1:  0, t2:  2, p2: 83
# 			 Total:100 					  767 / 3000 completed
#
# read:1457, recent:97 	 mode: recent
# fr:  6%, mr: 37% 	 f1:  1, f2: 46, p1:  5, m1:  0, m2: 36, t1:  0, t2: 12, p2:  0
# 			 Total:100 					  768 / 3000 completed
#
# read:697, recent:126 	 mode: recent
# fr: 60%, mr: 36% 	 f1:  1, f2: 41, p1:  5, m1:  1, m2: 34, t1:  0, t2: 18, p2:  0
# 			 Total:100 					  769 / 3000 completed
#
# read:526, recent:59 	 mode: recent
# fr: 57%, mr: 36% 	 f1:  1, f2: 69, p1:  3, m1:  0, m2: 21, t1:  0, t2:  6, p2:  0
# 			 Total:100 					  770 / 3000 completed
#
# read:32, recent:17 	 mode: recent
# fr:  0%, mr: 76% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2: 79, t1:  0, t2:  9, p2:  2
# 			 Total:100 					  771 / 3000 completed
#
# read:1097, recent:143 	 mode: recent
# fr: 67%, mr: 68% 	 f1:  4, f2: 91, p1:  0, m1:  0, m2:  0, t1:  0, t2:  5, p2:  0
# 			 Total:100 					  772 / 3000 completed
#
# read:93, recent:22 	 mode: recent
# fr:  0%, mr: 64% 	 f1:  0, f2:  0, p1: 10, m1:  1, m2: 80, t1:  0, t2:  9, p2:  0
# 			 Total:100 					  773 / 3000 completed
#
# read:87, recent:13 	 mode: recent
# fr: 15%, mr: 54% 	 f1:  0, f2:  2, p1:  9, m1:  0, m2: 74, t1:  0, t2: 15, p2:  0
# 			 Total:100 					  774 / 3000 completed
#
# read:70, recent:70 	 mode: recent
# fr: 16%, mr: 67% 	 f1:  1, f2: 46, p1:  5, m1:  2, m2: 12, t1:  0, t2:  7, p2: 27
# 			 Total:100 					  775 / 3000 completed
#
# read:295, recent:61 	 mode: recent
# fr: 18%, mr: 34% 	 f1:  0, f2: 77, p1:  2, m1:  0, m2: 15, t1:  0, t2:  6, p2:  0
# 			 Total:100 					  776 / 3000 completed
#
# read:132, recent:9 	 mode: recent
# fr: 67%, mr: 11% 	 f1:  9, f2: 49, p1:  4, m1:  0, m2: 38, t1:  0, t2:  0, p2:  0
# 			 Total:100 					  777 / 3000 completed
#
# read:516, recent:34 	 mode: recent
# fr: 35%, mr: 26% 	 f1:  0, f2: 56, p1:  4, m1:  0, m2: 30, t1:  0, t2: 10, p2:  0
# 			 Total:100 					  778 / 3000 completed
#
# read:22, recent:19 	 mode: recent
# fr:  0%, mr: 57% 	 f1:  0, f2:  0, p1: 10, m1:  1, m2: 82, t1:  0, t2:  2, p2:  5
# 			 Total:100 					  779 / 3000 completed
#
# read:160, recent:53 	 mode: recent
# fr:100%, mr: 23% 	 f1:  3, f2: 95, p1:  0, m1:  0, m2:  0, t1:  0, t2:  2, p2:  0
# 			 Total:100 					  780 / 3000 completed
#
# read:33, recent:16 	 mode: recent
# fr:  0%, mr: 88% 	 f1:  0, f2:  0, p1: 10, m1:  1, m2: 81, t1:  0, t2:  8, p2:  0
# 			 Total:100 					  781 / 3000 completed
#
# read:0, recent:0 	 mode: else
# fr:  0%, mr:  0% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2:  0, t1:  0, t2:  0, p2: 90
# 			 Total:100 					  782 / 3000 completed
#
# read:315, recent:46 	 mode: recent
# fr: 91%, mr: 28% 	 f1: 12, f2: 88, p1:  0, m1:  0, m2:  0, t1:  0, t2:  0, p2:  0
# 			 Total:100 					  783 / 3000 completed
#
# read:23, recent:1 	 mode: else
# fr: 22%, mr: 56% 	 f1:  2, f2: 59, p1:  3, m1:  1, m2: 26, t1:  0, t2:  2, p2:  7
# 			 Total:100 					  784 / 3000 completed
#
# read:705, recent:74 	 mode: recent
# fr:  4%, mr: 70% 	 f1:  0, f2:100, p1:  0, m1:  0, m2:  0, t1:  0, t2:  0, p2:  0
# 			 Total:100 					  785 / 3000 completed
#
# read:424, recent:24 	 mode: recent
# fr:100%, mr: 28% 	 f1:  1, f2: 87, p1:  1, m1:  0, m2:  8, t1:  0, t2:  3, p2:  0
# 			 Total:100 					  786 / 3000 completed
#
# read:31, recent:5 	 mode: read
# fr: 68%, mr: 61% 	 f1:  1, f2: 23, p1:  7, m1:  1, m2: 30, t1:  0, t2: 38, p2:  0
# 			 Total:100 					  787 / 3000 completed
#
# read:0, recent:0 	 mode: else
# fr:  0%, mr:  0% 	 f1:  0, f2:  0, p1: 10, m1:  0, m2:  0, t1:  0, t2:  0, p2: 90
# 			 Total:100 					  788 / 3000 completed
#
# read:4152, recent:473 	 mode: recent
# fr: 11%, mr: 30% 	 f1:  4, f2: 76, p1:  2, m1:  0, m2:  0, t1:  0, t2: 18, p2:  0
# 			 Total:100 					  789 / 3000 completed
#
# read:916, recent:62 	 mode: recent
# fr: 77%, mr: 32% 	 f1:  1, f2: 61, p1:  3, m1:  0, m2:  4, t1:  0, t2:  3, p2: 28
# 			 Total:100 					  790 / 3000 completed
#
# read:1702, recent:267 	 mode: recent
# fr:  2%, mr: 32% 	 f1:  1, f2: 73, p1:  2, m1:  0, m2:  2, t1:  0, t2: 22, p2:  0
# 			 Total:100 					  791 / 3000 completed
#
# read:956, recent:115 	 mode: recent
